# %% [markdown]
# # [NTDS'19] assignment 2: learning with graphs
# [ntds'19]: https://github.com/mdeff/ntds_2019
#
# [Clément Vignac](https://people.epfl.ch/clement.vignac), [EPFL LTS4](https://lts4.epfl.ch) and
# [Guillermo Ortiz Jiménez](https://gortizji.github.io), [EPFL LTS4](https://lts4.epfl.ch).

# %% [markdown]
# ## Students
#
# * Team: `6`
# * Students: `Altinigne, Can Yilmaz`,`Banjac, Jelena`,`Kypraiou, Sofia`,`Sioulas, Panagiotis`

# %% [markdown]
# ## Rules
#
# Grading:
# * The first deadline is for individual submissions. The second deadline is for the team submission.
# * All team members will receive the same grade based on the team solution submitted on the second deadline.
# * As a fallback, a team can ask for individual grading. In that case, solutions submitted on the first deadline are graded.
# * Collaboration between team members is encouraged. No collaboration between teams is allowed.
#
# Submission:
# * Textual answers shall be short. Typically one to two sentences.
# * Code has to be clean.
# * You cannot import any other library than we imported.
# * When submitting, the notebook is executed and the results are stored. I.e., if you open the notebook again it should show numerical results and plots. We won't be able to execute your notebooks.
# * The notebook is re-executed from a blank state before submission. That is to be sure it is reproducible. You can click "Kernel" then "Restart Kernel and Run All Cells" in Jupyter.

# %% [markdown]
# ## Objective
#
# In this assignment you will experiment with the main concepts of spectral graph theory, as well as familizarize yourself with the main data science techniques for network data.
#
# The assignment is made of three parts:
# 1. [Spectral Graph Theory](#sgt)
# 1. [Regularization on graphs with Graph Signal Processing](#gsp)
# 1. [Machine Learning on Graphs](#ml)

# %% [markdown]
# <a id='sgt'></a>
# ## Part I: Spectral Graph Theory
# ### Eigenvectors and eigenvalues
#
# We will start by reviewing some of the main concepts in spectral graph theory and see some of its applications to dimensionality reduction and data clustering. To illustrate the main concepts we will use the standard two moon dataset.

# %%
import numpy as np
from scipy.spatial.distance import pdist, squareform, euclidean
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib inline

# %%
from pygsp.graphs import TwoMoons

G = TwoMoons(moontype='synthesized', N=2000)
X = G.coords
Y = G.labels.astype(int)

plt.figure(figsize=(9,7))
plt.scatter(X[:, 0], X[:, 1], c=Y)
plt.show()

# %%
X.shape
# Out:
# (2000, 2)

# %% [markdown]
# #### Question 1: Graph construction
# Build a similarity graph using the euclidean distance between data points.
# **Note:** Use an RBF kernel to set the edge weights $w_{ij}=\exp(-||x_i- x_j||_2^2 / ~ 2 \sigma^2)$ of your adjacency and threshold the ones with the smallest magnitude.

# %%
def epsilon_similarity_graph(X: np.ndarray, sigma=1, epsilon=0):
    """ X (n x d): coordinates of the n data points in R^d.
        sigma (float): width of the kernel
        epsilon (float): threshold
        Return:
        adjacency (n x n ndarray): adjacency matrix of the graph.
    """
    n = X.shape[0]
    adjacency = np.zeros((n, n))
    for i in range(n):
        for j in range(i+1,n):
            w = np.exp(-euclidean(X[i], X[j])**2/(2*sigma**2))
            adjacency[i, j] = adjacency[j, i] = w if w > epsilon else 0
    
    return adjacency

# %%
sigma = 0.85
epsilon = np.exp(-0.8**2/(2*sigma**2))
print(f"sigma={sigma}, epsilon={epsilon}")

adjacency = epsilon_similarity_graph(X, sigma=sigma, epsilon=epsilon)
plt.figure(figsize=(7,7))
plt.spy(adjacency)
plt.show()
# Out:
# sigma=0.85, epsilon=0.64216719914479

# %% [markdown]
# <div class="alert alert-success">
#     <b>NOTE (for us):</b>
#     Edge weights (w) are set with RBF kernel:
#
#    - range from 0 to 1
#    - decreases with distance (e.g. 0 for far points, 1 to same/close points)
#
# The goal is to have as many connections as possible in $A[:1000,:1000]$ and $A[1000:,1000:]$ regions, and no connections otherwise. So, we want small distances to give high weight to that edge.
# When $\sigma$->0 all edges will be given the small weight.
# When $\sigma$->1, the edges that are clossest will be given high weight.
# </div>

# %% [markdown]
# How do you choose `sigma`?

# %% [markdown]
# <div class="alert alert-info">
#     <b>ANSWER:</b>
#     We can choose any $\sigma$ value since it will be filtered out with $\epsilon$. However, we will prefer the higher sigma value since it will give more weight on the edges of small distances. We choose $\sigma$ = <b>0.85</b>.
# </div>

# %% [markdown]
# How do you choose the threshold `epsilon`?

# %% [markdown]
# <div class="alert alert-info">
#     <b>ANSWER:</b>
#     Depending on the $\sigma$ value, we choose $\epsilon$ value based on equation  $\epsilon = \exp(-0.35^2 / ~ 2 \sigma^2)$. The value 0.35 is measured from the Two Moons plot, where it is the distance between one end of the one moon and the middle point of the other moon. We calculate it $\epsilon$ = <b>0.92</b>.
# </div>

# %% [markdown]
# #### Question 2: Laplacian
# Build the combinatorial and normalized graph laplacians for this dataset.

# %%
def compute_laplacian(adjacency: np.ndarray, normalize: bool):
    """ Return:
        L (n x n ndarray): combinatorial or symmetric normalized Laplacian.
    """
    # Your code here
    n = adjacency.shape[0]
    
    # D is degree matrix (in our case the degree is represented with the weight of edge)
    D = np.diag(np.sum(adjacency, axis=1))
    L = D - adjacency
    
    if not normalize:
        return L

    # L_norm = D^(-1/2) @ L @ D^(-1/2)
    D_norm = np.diag(np.sum(adjacency, axis=1)**(-0.5))
    L_norm = D_norm @ L @ D_norm
    
    return L_norm

# %%
laplacian_comb = compute_laplacian(adjacency, normalize=False)
laplacian_norm = compute_laplacian(adjacency, normalize=True)

# %% [markdown]
# #### Question 3: Eigendecomposition
#
# For both Laplacian matrices, compute the eigendecomposition $L = U^\top \Lambda U$, where the columns $u_k \in \mathbb{R}^N$ of $U = [u_1, \dots, u_N] \in \mathbb{R}^{N \times N}$ are the eigenvectors and the diagonal elements $\lambda_k = \Lambda_{kk}$ are the corresponding eigenvalues. Make sure that the eigenvalues are ordered, i.e., $\lambda_1 \leq \lambda_2 \leq \dots \leq \lambda_N$.
#
# Justify your choice of a solver for the eigendecomposition.

# %% [markdown]
# <div class="alert alert-info">
#     <b>ANSWER:</b>
#     The Laplacian is always a symmetric real valued matrix and therefore a Hermitian matrix as well. So we can use the solver for sparse Hermitian matrices.
# </div>

# %%
def spectral_decomposition(laplacian: np.ndarray):
    """ Return:
        lamb (np.array): eigenvalues of the Laplacian
        U (np.ndarray): corresponding eigenvectors.
    """
    # Your code here
    lamb, U = np.linalg.eig(laplacian)
    
    #order the eigenvalues
    sortInd = np.argsort(lamb)
    
    return lamb[sortInd], U[:, sortInd]

# %%
lamb_comb, U_comb = spectral_decomposition(laplacian_comb)
lamb_norm, U_norm = spectral_decomposition(laplacian_norm)

# %% [markdown]
# #### Question 4: Interpretation
# We plot the sorted eigenvalues as a function of their index:

# %%
plt.figure(figsize=(12,5))
plt.subplot(121)
plt.plot(lamb_comb)
plt.xlabel('Index')
plt.ylabel('Eigenvalue')
plt.title('Eigenvalues $L_{comb}$')
plt.subplot(122)
plt.plot(lamb_norm)
plt.xlabel('Index')
plt.ylabel('Eigenvalue')
plt.title('Eigenvalues $L_{norm}$')
plt.show()

# %% [markdown]
# What is the lowest eigenvalue $\lambda_0$ and the corresponding eigenvector $u_0$? Answer for both Laplacian matrices.

# %% [markdown]
# <div class="alert alert-info">
#     <b>ANSWER:</b> https://github.com/mdeff/ntds_2018/blob/master/milestones/3_spectral_graph_theory_student_solution.ipynb
#     If the graph (W) has K connected components, then L has K eigenvectors with an eigenvalue of 0.
# </div>

# %% [markdown]
# When filtering a signal or computing polynomials, which Laplacian provides the best numerical stability? Justify your answer.

# %% [markdown]
# <div class="alert alert-info">
#     <b>ANSWER</b>
#
# </div>

# %% [markdown]
# #### Question 5: Connected components
# The eigendecomposition provides an easy way to compute the number of connected components in the graph. Fill the following function:

# %%
def compute_number_connected_components(lamb: np.array, threshold: float):
    """ lamb: array of eigenvalues of a Laplacian
        Return:
        n_components (int): number of connected components.
    """
    # Your code here
    return lamb[lamb < threshold].shape[0]

# %% [markdown]
# Tune the parameters $\epsilon$ and $\sigma$ of the similarity graph so that the graph is connected. Otherwise, clustering would be too simple!

# %%
# added cell for tuning the params for graph being connected
sigma = 0.1
epsilon = np.exp(-1**2/(2*sigma**2))
print(f"sigma={sigma}, epsilon={epsilon}")

laplacian_norm = compute_laplacian(adjacency, normalize=True)
lamb_norm, U_norm = spectral_decomposition(laplacian_norm)

adjacency = epsilon_similarity_graph(X, sigma=sigma, epsilon=epsilon)
plt.figure(figsize=(7,7))
plt.spy(adjacency)
plt.show()
# Out:
# sigma=0.1, epsilon=1.9287498479639315e-22

# %%
print(compute_number_connected_components(lamb_norm, threshold=0.0005))#1e-12))
# Out:
# 2

# %% [markdown]
# <div class="alert alert-danger">
#     <b>Check the output: 1 or 2 components?</b>
#
# </div>

# %% [markdown]
# ### Spectral clustering
#
# Let us now see one application of spectral graph theory to clustering the two moon dataset.
#
# #### Question 6: Baseline
#
# As a baseline, let us first see how the simplest clustering algorithm, K-means, performs on this dataset. Use K-means to assign a cluster to each point.

# %%
from sklearn.cluster import KMeans

# Your code here
y_pred =  KMeans(n_clusters=2, random_state=0).fit_predict(X) # Vector with cluster assignments

plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.show()

# %% [markdown]
# K-means cannot find a good solution to this problem. Why?

# %% [markdown]
# <div class="alert alert-info">
#     <b>ANSWER</b>
#     K-means clustering aims to partition $n$ observations into $k$ clusters in which each observation belongs to the cluster with the nearest mean. Therefore, the K-means cannot find a good solution to this problem since it is using the absolute location (which in this case are should not be belonging to the same cluster) to determine what poitns fall under which cluster.
# </div>

# %% [markdown]
# #### Question 7: Spectral clustering
#
# As opposed to naive K-means, spectral clustering doesn't operate on the input space but on the eigenspace of the graph that represents the data. Implement spectral clustering. You can use
# [this tutorial](http://lasa.epfl.ch/teaching/lectures/ML_Phd/Notes/tutoSC.pdf).

# %%
class SpectralClustering():
    def __init__(self, n_classes: int, normalize: bool):
        self.n_classes = n_classes
        self.normalize = normalize
        self.laplacian = None
        self.e = None
        self.U = None
        # Your code here
        self.clustering_method =  KMeans(n_clusters=n_classes, random_state=0)
        
    def fit_predict(self, adjacency):
        """ Your code should be correct both for the combinatorial
            and the symmetric normalized spectral clustering.
            Return:
            y_pred (np.ndarray): cluster assignments.
        """
        # Your code here
        self.laplacian = compute_laplacian(adjacency, self.normalize)
        self.e, self.U = spectral_decomposition(self.laplacian)
        self.U = self.U[:,:self.n_classes]
        
        if self.normalize:
            self.U /= np.sqrt(np.sum(self.U**2,axis=1))[:, np.newaxis]
            
        y_pred = self.clustering_method.fit_predict(self.U)
        
        
        return y_pred

# %%
print("Connected components:", compute_number_connected_components(lamb_norm, threshold=1e-12))
spectral_clustering = SpectralClustering(n_classes=2, normalize=True)
y_pred = spectral_clustering.fit_predict(adjacency)
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.show()
# Out:
# Connected components: 1

# %% [markdown]
# <div class="alert alert-danger">
#     <b>Check the output: 1 or 2 components?</b>
#
# </div>

# %% [markdown]
# #### Question 8: On your dataset
#
# Can you think of another 2D dataset in which k-means would badly perform, but spectral clustering would not?
# Construct it!
# For this question you can import any dataset of your choice, for example from `sklearn.datasets` or `pygsp.graphs`, but you can also get creative and define something of your own. First, create and plot the dataset.

# %%
# Your code here
from sklearn.datasets import make_circles

X, y = make_circles(n_samples=2000, random_state=0, noise=0.02, factor=0.6)
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

# %% [markdown]
# Run K-means:

# %%
# Your code here
y_pred = KMeans(n_clusters=2, random_state=0).fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.show()

# %% [markdown]
# Create the similarity graph, and run spectral clustering with both the combinatorial and normalized Laplacian matrices:

# %%
# Your code here
adjacency = epsilon_similarity_graph(X, sigma=0.25, epsilon=0.5)

f, ax = plt.subplots(1,2, figsize=(10,4))
ax = ax.ravel()
norm = [True, False]

for i in range(2):  
    spectral_clustering = SpectralClustering(n_classes=2, normalize=norm[i])
    y_pred = spectral_clustering.fit_predict(adjacency)
    ax[i].scatter(X[:, 0], X[:, 1], c=y_pred)
    ax[i].set_title("Normalized = " + str(norm[i]))

# %% [markdown]
# <div class="alert alert-info">
#     <b>ANSWER</b>
#     *Comment your results here*
# </div>

# %% [markdown]
# ### Dimensionality Reduction with Laplacian Eigenmaps
#
# Most datasets are very high-dimensional, which means it can be very hard to understand their geometry. Fortunately, there exists multiple  techniques that can help us to reduce the dimensionality of the data, and allow us to visualize it.
#
# In this part of the assignment we will use MNIST to compare these techniques. Indeed, without dimensionality reduction it would be very difficult to answer questions like: are the different digits clustered together in different areas of space?
#
# But first, let's load our dataset:

# %%
from utils import load_mnist
import numpy as np

X_mnist, y_mnist = load_mnist()
classes = np.unique(y_mnist)

# %% [markdown]
# #### Question 9: Laplacian eigenmaps
#
# Most dimensionality reduction algorithms are constructed such that some property of the dataset remains invariant in the lower dimensional representation. Before implementing laplacian eigenmaps, can you say what property of the data does this algorithm preserve?

# %% [markdown]
# <div class="alert alert-info">
#     <b>ANSWER:</b>
#      We use Laplacian eigenmaps for dimensionality reduction, mapping a network to a vector space and reducing the dimension, while preserving relevant graph properties. It preserves relevant graphs properties such as the number of data points N, while reducing the dimension d. The goal of the Laplacian eigenmap algorithm is to preserve local information optimally. All the point node that are close to each other, meaning nodes connected by an edge with a large weight, must remain close to each other in the embedding (local distances).
# </div>

# %% [markdown]
# Implement a function that uses Laplacian eigenmaps to do dimensionality reduction.

# %%
euclidean(X_mnist[300], X_mnist[301])
# Out:
# 2354.3323894471655

# %%
sigma= 1400
np.exp(-euclidean(X_mnist[700], X_mnist[701])**2/(2*sigma**2))
# Out:
# 0.3749786363042903

# %%
e = []
for n in range(10):
    for i in range(n, n+300):
        for j in (i, n+300):
            e.append(euclidean(X_mnist[i], X_mnist[j]))
np.mean(e)
# Out:
# 1435.5480691390171

# %%
sigma=5000
eps = []
for n in range(10):
    for i in range(n, n+300):
        for j in (i, n+300):
            eps.append(np.exp(-euclidean(X_mnist[i], X_mnist[j])**2/(2*sigma**2)))
print(np.mean(eps))
print(np.median(eps))
# Out:
# 0.9234678800162379
# 0.998242595725834

# %%
def laplacian_eigenmaps(X:np.ndarray, dim: int, sigma: float, epsilon: float, normalize: bool, plotting=False):
    """ Return:
        coords (n x dim array): new coordinates for the data points."""
    # Your code here
    adjacency = epsilon_similarity_graph(X, sigma, epsilon)
    if plotting:
        plt.figure(figsize=(7,7))
        plt.spy(adjacency)
        plt.show()
    
    laplacian = compute_laplacian(adjacency, normalize)
    e, U = spectral_decomposition(laplacian)
    
    # solutions are the k first non-trivial eigenvectors of L_norm
    nonZeroInd = np.nonzero(e)[0]
    dimInd = nonZeroInd[:dim+1]  # TODO: was +1
    
    # select the n classes 
    coords = U[:,dimInd]

    return coords

# %%
Xcoords = laplacian_eigenmaps(X_mnist, dim=8, sigma=5000, epsilon=0.5, normalize=True, plotting=False);

# %% [markdown]
# <div class="alert alert-danger">
#     <b>NOTE:</b>
#      Euclidean distance between two images here is very high in comparison to the dataset we had in the questions in the beginning of the notebook. Therefore, the sigma value would need to be very big.
# </div>

# %% [markdown]
# Use this function to visualize MNIST in 2D. Feel free to play with the different parameters.

# %%
# Your code here
dim = 2

for number, i in enumerate(range(0, 3000, 300)):
    plt.scatter(Xcoords[i:i+300, 1], Xcoords[i:i+300, 2], label=f"{number}")

plt.legend()
plt.show()

# %% [markdown]
# Visualize MNIST in 3D:

# %%
# Your code here
dim = 3

fig = plt.figure()
ax = Axes3D(fig)
for number, i in enumerate(range(0, 3000, 300)):
    ax.scatter(Xcoords[i:i+300, 1], Xcoords[i:i+300, 2], Xcoords[i:i+300,3], label=f"{number}")
plt.legend()
plt.show()

# %% [markdown]
# <div class="alert alert-danger">
#     <b>NOTE:</b>
#      We also tried to see the result of a different epsilon value, which will concentrate on the MNIST images that are more similar. From the output below we can see that the images of numbers 0 and 2 are tending to be very close in sence of differences. However, all other numbers are clustered around (0, 0) coordinates so we cannot really distinguish them.
# </div>

# %%
Xcoords = laplacian_eigenmaps(X_mnist, dim=8, sigma=5000, epsilon=0.9, normalize=True, plotting=False);

# %%
for number, i in enumerate(range(0, 3000, 300)):
    plt.scatter(Xcoords[i:i+300, 1], Xcoords[i:i+300, 2], label=f"{number}")

plt.legend()
plt.show()

# %%
# Your code here
dim = 3

fig = plt.figure()
ax = Axes3D(fig)
for number, i in enumerate(range(0, 3000, 300)):
    ax.scatter(Xcoords[i:i+300, 1], Xcoords[i:i+300, 2], Xcoords[i:i+300,3], label=f"{number}")
plt.legend()
plt.show()

# %% [markdown]
# #### Question 10: Comparison with other methods
# We provide the visualization of MNIST with other methods:

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE, Isomap

# This cell can take a few minutes to run
run_this_cell = True

if run_this_cell:
    # In 2d
    embeddings = [PCA(n_components=2, copy=True, whiten=True, tol=1e-5),
                  Isomap(n_components=2, n_neighbors=5),
                  TSNE(n_components=2)]

    for embedding in embeddings:
        X_embedded = embedding.fit_transform(X_mnist)
        fig = plt.figure()
        for i in classes:
            mask = y_mnist == i
            plt.scatter(X_embedded[mask, 0], X_embedded[mask, 1], label=i)
        plt.legend()
        plt.title('Embedding method: '+ type(embedding).__name__)
        plt.show()

    # In 3d
    embeddings = [PCA(n_components=3, copy=True, whiten=True, tol=1e-5),
                  Isomap(n_components=3, n_neighbors=5),
                  TSNE(n_components=3)]

    for embedding in embeddings:
        X_embedded = embedding.fit_transform(X_mnist)
        fig = plt.figure()
        ax = Axes3D(fig)
        for i in classes:
            mask = y_mnist == i
            ax.scatter(X_embedded[mask, 0], X_embedded[mask, 1], X_embedded[mask, 2], label=i)
        ax.legend()
        ax.title.set_text('Embedding method: '+ type(embedding).__name__)
        plt.show()

# %% [markdown]
# In a few words, what are the principles guiding the design of each method? Compare their results.

# %% [markdown]
# <div class="alert alert-info">
#     <b>ANSWER:</b>
#     https://scikit-learn.org/stable/modules/manifold.html
#
# https://scikit-learn.org/stable/auto_examples/manifold/plot_lle_digits.html
# </div>

# %% [markdown]
# <a id='gsp'></a>
# ## Part II: Regularization on graphs with Graph Signal Processing
#
# In this part of the assignment we are going to familiarize ourselves with the main concepts in Graph Signal Processing and regularization on graphs in general. From now on, you can only use the following libraries as well as the functions that you implemented in the previous parts.

# %%
import pandas as pd
import numpy as np
from pygsp.graphs import Bunny

# %% [markdown]
# In this exercise we will use a nearest-neighbor graph constructed from the Stanford Bunny point cloud included in the PyGSP library.

# %%
G = Bunny()
adjacency = np.asarray(G.W.todense())
n_nodes = adjacency.shape[0]

# %% [markdown]
# We will use the following function to plot our signals on this graph.

# %%
def plot_bunny(x=None, title='', vlim=[-0.03, 0.03]):
    fig = plt.gcf()
    ax = plt.gca()
    if not isinstance(ax, Axes3D):
        ax = plt.subplot(111, projection='3d')
    if x is not None:
        x = np.squeeze(x)

    p = ax.scatter(G.coords[:,0], G.coords[:,1], G.coords[:,2], c=x, marker='o',
                   s=5, cmap='RdBu_r', vmin=vlim[0], vmax=vlim[1])
    ax.view_init(elev=-90, azim=90)
    ax.dist = 7
    ax.set_axis_off()
    ax.set_title(title)
    if x is not None:
        fig.colorbar(p)

# %%
plt.subplot(111, projection='3d')
plot_bunny()

# %% [markdown]
# #### Question 11: Graph frequencies
#
# Let us start by constructing the normalized graph laplacians from the adjacency matrix and find its spectral decomposition.

# %%
laplacian = compute_laplacian(adjacency, normalize=True)
lam, U = spectral_decomposition(laplacian)

# %% [markdown]
# Plot the eigenvalues.

# %%
plt.figure(figsize=(6, 5))
plt.plot(lam)
plt.title('Eigenvalues $L_{norm}$')
plt.show()

# %% [markdown]
# To make things more clear we will plot some of its eigenvectors (0, 1, 3, 10, 100) as signals on the bunny graph.

# %%
plt.figure(figsize=(18, 9))
plt.subplot(231, projection='3d')
plot_bunny(x=U[:,0], title='Eigenvector #0')
plt.subplot(232, projection='3d')
plot_bunny(x=U[:,1], title='Eigenvector #1')
plt.subplot(233, projection='3d')
plot_bunny(x=U[:,2], title='Eigenvector #2')

plt.subplot(234, projection='3d')
plot_bunny(x=U[:,3], title='Eigenvector #3')
plt.subplot(235, projection='3d')
plot_bunny(x=U[:,10], title='Eigenvector #10')
plt.subplot(236, projection='3d')
plot_bunny(x=U[:,100], title='Eigenvector #100')

# %% [markdown]
# What can you say in terms of the variation (smoothness) of these signals? How can the smoothness of a signal be measured?

# %% [markdown]
# <div class="alert alert-info">
#     <b>ANSWER</b>
#
# </div>

# %% [markdown]
# #### Question 12: Graph Fourier Transform
#
# Create a function to compute the Graph Fourier Transform (GFT) of a graph signal and its inverse.
# **Note**: You can assume that you have internal access to the eigendecomposition (`U` and `lam`) of the laplacian.

# %%
def GFT(signal: np.ndarray):
    # Your code here
    return U.T @ signal

def iGFT(fourier_coefficients: np.ndarray):
    # Your code here
    return U @ fourier_coefficients

# %% [markdown]
# Now, let's create a graph signal:

# %%
x = G.coords[:, 0] + G.coords[:, 1] + 3 * G.coords[:, 2]
x /= np.linalg.norm(x) 

noise = np.random.randn(n_nodes)
noise /= np.linalg.norm(noise) 

x_noisy = x + 0.3*noise

plot_bunny(x_noisy, vlim=[min(x_noisy), max(x_noisy)])
# Out:
# /home/jelena/.local/lib/python3.7/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %% [markdown]
# and plot its graph spectrum:

# %%
plt.figure(figsize=(10, 6))
plt.plot(lam, np.abs(GFT(x_noisy)), 'r.') 
plt.plot(lam, np.abs(GFT(x)), 'g-')
plt.xlabel('$\lambda$')
plt.ylabel('GFT')
plt.legend(['$x_{noisy}$', '$x$'])

# %% [markdown]
# #### Question 13: Graph filters
#
# We will try to extract the signal from the noise using graph filters. Let us start by creating three ideal graph filters.

# %%
ideal_lp = np.ones((n_nodes,))
ideal_bp = np.ones((n_nodes,))
ideal_hp = np.ones((n_nodes,))

ideal_lp[lam >= 0.1] = 0  # Low-pass filter with cut-off at lambda=0.1
ideal_bp[lam < 0.1] = 0  # Band-pass filter with cut-offs at lambda=0.1 and lambda=0.5
ideal_bp[lam > 0.5] = 0
ideal_hp[lam <= 1] = 0  # High-pass filter with cut-off at lambda=1

# %% [markdown]
# Additionally, create the ideal graph filter that implements the solution of Tikhonov regularization.

# %%
# alpha = 0.99 / np.max(lam)

# # Your code here
# X = np.identity(len(lam))
# I = laplacian #np.identity(len(lam))
# y = lam

# ideal_tk = np.dot(np.dot(np.linalg.inv(np.dot(X.T, X) + alpha * I), X.T), y)

# %%
alpha = 0.99 / np.max(lam)

ideal_tk = np.zeros(laplacian.shape[0])
for i in range(laplacian.shape[0]) :
    ideal_tk[i] = 1.0/(1.0+alpha*lam[i])

# %% [markdown]
# Let's plot the spectral responses:

# %%
plt.plot(lam, ideal_lp, '-', label='LP')
plt.plot(lam, ideal_bp, '-', label='BP')
plt.plot(lam, ideal_hp, '-', label='HP')
plt.plot(lam, ideal_tk, '-', label='Tikhonov')
plt.xlabel('$\lambda$')
plt.ylabel('Spectral response')
plt.legend(loc='lower right');

# %% [markdown]
# <div class="alert alert-danger">
#     <b>TODO: I think the TK should be smooth, and not like this!!! CHECK!</b>
#
# </div>

# %% [markdown]
# Create a function to filter a signal given an ideal graph filter

# %%
def ideal_graph_filter(x: np.ndarray, spectral_response: np.ndarray):
    """Return a filtered signal."""
    # Your code here       
    return iGFT(spectral_response * GFT(x))

# %% [markdown]
# Let us visualize the results:

# %%
x_lp = ideal_graph_filter(x_noisy,ideal_lp)
x_bp = ideal_graph_filter(x_noisy,ideal_bp)
x_hp = ideal_graph_filter(x_noisy,ideal_hp)
x_tk = ideal_graph_filter(x_noisy,ideal_tk)

plt.figure(figsize=(18, 9))
plt.subplot(231, projection='3d')
plot_bunny(x=x, title='signal (true)', vlim=[min(x), max(x)])
plt.subplot(232, projection='3d')
plot_bunny(x=x_noisy, title='signal (noisy)', vlim=[min(x), max(x)])
plt.subplot(233, projection='3d')
plot_bunny(x=x_lp, title='Low-pass', vlim=[min(x_lp), max(x_lp)])
plt.subplot(234, projection='3d')
plot_bunny(x=x_bp, title='Band-pass', vlim=[min(x_bp), max(x_bp)])
plt.subplot(235, projection='3d')
plot_bunny(x=x_hp, title='High-pass', vlim=[min(x_hp), max(x_hp)])
plt.subplot(236, projection='3d')
plot_bunny(x=x_tk, title='Tikhonov denoised signal', vlim=[min(x_tk), max(x_tk)])

# %% [markdown]
# How would you link to the observations you made before about the spectral decomposition of the laplacian?
# Also, judging from the results, what type of model prior do you think Tikhonov regularization enforces?

# %% [markdown]
# <div class="alert alert-info">
#     <b>ANSWER</b>
# </div>

# %% [markdown]
# #### Question 14: Polynomial graph filters
#
# We have seen how we can use the GFT to define different filters that enhance or reduce certain frequency bands. However, to do so, we require an explicit eigendecomposition of the graph laplacian, which has a cost $O(n^3)$. For very large graphs this is very intense computationally. We will now see how we can obtain similar results by filtering the signals directly without resorting to an eigendecomposition.
#
# The key idea is to use a polynomial of the graph laplacian to define a graph filter, i.e., $g(L)x=\sum_{k=1}^K \alpha_k L^k x$, and use the fact that the powers of a diagonalizable matrix can be written in terms of powers of its eigenvalues. This is
# $$
# L^k=(U\Lambda U^T)^k=U\Lambda^k U^T = U\begin{bmatrix}
# (\lambda_0)^k &\dots & 0\\
# \vdots & \ddots & \vdots\\
# 0 & \dots & (\lambda_N)^k
# \end{bmatrix} U^T.
# $$
#
# This means that a polynomial of the graph laplacian acts independently on each eigenvalue of the graph, and has a frequency spectrum of
# $$g(\lambda)=\sum_{k=1}^K \alpha_k \lambda^k.$$
# Hence,
# $$g(L)x=\sum_{k=1}^K \alpha_k L^k x=\sum_{k=1}^K \alpha_k U\Lambda^k U^T x=U \left(\sum_{k=1}^K \alpha_k\Lambda^k \right)U^T x=\operatorname{iGFT}\left(g(\Lambda)\operatorname{GFT}(x)\right).$$
#
# With these ingredients, we have reduced the design of graph filters in the vertex domain to a regression task that approximates a given spectral response by a polynomial. There are multiple ways to do this, but in this assignment we will implement a very simple strategy based on [least-squares regression](https://en.wikipedia.org/wiki/Polynomial_regression#Matrix_form_and_calculation_of_estimates).

# %% [markdown]
# Implement a function to find the coefficients of a polynomial that approximates a given ideal filter.
# **Hint:** `np.vander` and `np.linalg.lstsq`.

# %%
def fit_polynomial(lam: np.ndarray, order: int, spectral_response: np.ndarray):
    """ Return an array of polynomial coefficients of length 'order'."""
    # Your code here
    vander = np.vander(lam, N=order+1, increasing=True)
    fit = np.linalg.lstsq(vander, spectral_response)[0]
    return fit

# %% [markdown]
# Implement a function to compute the frequency response of that filter.

# %%
def polynomial_graph_filter_response(coeff: np.array, lam: np.ndarray):
    """ Return an array of the same shape as lam.
        response[i] is the spectral response at frequency lam[i]. """
    return np.vander(lam, N=len(coeff), increasing=True) @ coeff

# %% [markdown]
# Let us fit the Tikhonov ideal filter with several polynomials of different order.

# %%
plt.plot(lam, ideal_tk)
orders = [1, 2, 3, 5, 10, 20]
for order in orders:    
    coeff_tk = fit_polynomial(lam, order, ideal_tk)
    plt.plot(lam, polynomial_graph_filter_response(coeff_tk, lam))

plt.xlabel('$\lambda$')
plt.ylabel('Spectral response')
plt.legend(orders)
# Out:
# /home/jelena/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   """

# %% [markdown]
# So far, we have only defined a way to compute the coefficients of our laplacian polynomial. Let us now compute our graph filter.

# %%
def polynomial_graph_filter(coeff: np.array, laplacian: np.ndarray):
    """ Return the laplacian polynomial with coefficients 'coeff'. """
    # Your code here
    aggr = np.zeros((laplacian.shape[0], laplacian.shape[1]))
    for i in range(coeff.shape[0]) :
        aggr += coeff[i]*np.linalg.matrix_power(laplacian, i)
    return aggr

# %% [markdown]
# Based on the previous plot, choose a filter order that achieves (in your opinion) a good tradeoff in terms of computational complexity and response accuracy.

# %%
order =  3 # Your code here
coeff_tk = fit_polynomial(lam, order, ideal_tk)
g_tk = polynomial_graph_filter(coeff_tk, laplacian)

# %% [markdown]
# #### Question 15: ARMA filter
#
# As you have seen in class, polynomial graph filters are only one of the ways in which you can approximate ideal graph filters.
# In this sense, ARMA filters are a natural way to implement Tikhonov denoising on graphs.
# Let us recall the general solution of the Tikhonov regularized denoising problem
#
# $$y=(I+\alpha L)^{-1}x. $$
#
# With a little bit of algebra manipulation we can rewrite this expression as
# $$
#     y = -\alpha L y + x,
# $$
# from which we can derive the iterative algorithm
# $$
#     y_k = -\alpha L y_{k-1} + x\qquad k=1,2,\dots
# $$
# which is guaranteed to converge as long as $\alpha \lambda_{max} < 1$.

# %% [markdown]
# Implement the ARMA version of Tikhonov regularization.

# %%
def arma_tikhonov(x: np.ndarray, laplacian: np.ndarray, alpha: float, max_iter=50):
    """ Return an array of the same shape as x."""
    # Your code here
    y = np.ones((x.shape[0],1))
    for i in range(max_iter) :
        z = (-alpha * laplacian) @ y + x[:,None]
        y = z
    return y

# %% [markdown]
# Filter the previous noisy graph signal with the polynomial and ARMA approximations of the ideal Tikhonov filter.

# %%
x_tk_polynomial = g_tk @ x_noisy # Your code here
x_tk_arma = arma_tikhonov(x_noisy, laplacian, alpha)

# %% [markdown]
# Let us compare with the previous version.

# %%
plt.figure(figsize=(18, 4))
plt.subplot(131, projection='3d')
plot_bunny(x_tk, title='Ideal filter', vlim=[min(x_tk), max(x_tk)])
plt.subplot(132, projection='3d')
plot_bunny(x_tk_polynomial, title='Polynomial filter', vlim=[min(x_tk), max(x_tk)])
plt.subplot(133, projection='3d')
plot_bunny(x_tk_arma, title='ARMA filter', vlim=[min(x_tk), max(x_tk)])

# %% [markdown]
# <a id='ml'></a>
# ## Part III: Machine Learning on Graphs
#
# So far, we have only played with toy examples. Let us see the use of these tools in practice! In particular, let us see how we can use some graph filters to construct features to feed a classifier. For this part of the assignment we will import some extra packages.

# %%
import time

import networkx as nx
from sklearn.linear_model import LogisticRegression

import torch
import torch.nn as nn
import torch.nn.functional as F

import dgl.function as fn
from dgl import DGLGraph
from dgl.data.citation_graph import load_cora

np.random.seed(0)
torch.manual_seed(1)

# %% [markdown]
# We will use the CORA dataset and the citation graph that we created in Assignment 1. However, to simplify the next tasks we will directly use the preprocessed version of this dataset contained within the Deep Graph Library (DGL).
#
# In this assignment, we will interpret CORA's features as multidimensional graph signals living on the citation graph.
# Our task is to design a classifier that uses these features and the geometry of the graph can identify the type of paper each node represents.
#
# The goal of this exercise is to do semi-supervised learning on graphs.
# We assume that we know to which scientific field a small subset of the papers belongs (the ones contained in `train_mask`).
# The goal is to predict to which field the other papers belong, using both the citation graph and the bag-of-word representation of each paper.

# %%
cora = load_cora()

features = torch.FloatTensor(cora.features)    # Feature vector for each paper
labels = torch.LongTensor(cora.labels)         # The field to which each paper belongs

train_mask = torch.BoolTensor(cora.train_mask) # Mask of nodes selected for training
val_mask = torch.BoolTensor(cora.val_mask)     # Mask of nodes selected for validation
test_mask = torch.BoolTensor(cora.test_mask)   # Mask of nodes selected for testing

in_feats = features.shape[1]
n_classes = cora.num_labels
n_edges = cora.graph.number_of_edges()

graph = cora.graph
adjacency = np.asarray(nx.to_numpy_matrix(graph))
n_nodes = adjacency.shape[0]

# %% [markdown]
# For this exercise we will use the normalized laplacian.

# %%
laplacian = compute_laplacian(adjacency, normalize=True)
lam, U = spectral_decomposition(laplacian)
lam_max = np.max(lam)

# %%
lam.shape
# Out:
# (2708,)

# %% [markdown]
# #### Question 16: Logistic regression
#
# The simplest classification method consists in ignoring the citation graph and trying to classify the papers using only the features.
# In this case, the problem is viewed as a standard classification task.
# To train our classifier we will select a few nodes in our graph for training and fit a [logistic regression classifier](https://en.wikipedia.org/wiki/Logistic_regression) on them.
# To avoid overfitting to the test set when we do hyperparameter tuning, we will also select a validation set.
# And finally, we will test our classifier on the rest of the nodes.
# **Hint:** use `sklearn.linear_model.LogisticRegression`.

# %%
train_features = features[train_mask]
train_labels = labels[train_mask]
val_features = features[val_mask]
val_labels = labels[val_mask]
test_features = features[test_mask]
test_labels = labels[test_mask]

# %%
train_features.shape, train_labels.shape
# Out:
# (torch.Size([140, 1433]), torch.Size([140]))

# %%
# Fit a logistic regression model
# Your code here
from sklearn.metrics import accuracy_score
# 8e6
#C_param_range = [0.001,0.01,0.1,1,10,100, 1000, 5000, 1e4, 1e6, 8e6, 9e6, 1e7, 2e7,1e8]

try:
    C_param_range = np.arange(1e6, 1e8, 1e3)
    accuracies_train = []
    accuracies_val   = []
    params = []

    j = 0
    for i in C_param_range:

        # Apply logistic regression model to training data
        lr = LogisticRegression(penalty = 'l2', C = i, random_state = 0, solver='lbfgs', multi_class='multinomial', max_iter=1e5)

        # Predict using model
        y_pred_train = lr.fit(train_features, train_labels).predict(test_features)
        y_pred_val   = lr.fit(val_features, val_labels).predict(test_features)

        # Calculate accuracy
        acc_train = accuracy_score(test_labels, y_pred_train)
        acc_val   = accuracy_score(test_labels, y_pred_val)
        
        # Collect
        accuracies_train.append(acc_train)
        accuracies_val.append(acc_val)
        params.append(i)

except KeyboardInterrupt:
    pass
finally:
    plt.figure(figsize=(10,7))
    plt.plot(params, accuracies_train, label="train")
    plt.plot(params, accuracies_val, label="val")
    plt.legend()
    print(max(accuracies_train), max(accuracies_val))
# Out:
# 0.594 0.653

# %%
accuracies_mean = [ (t+v)/2 for (t, v) in zip(accuracies_train, accuracies_val)]
i = (np.argmax(accuracies_mean))
accuracies_mean[i], params[i]
# Out:
# (0.621, 1115000.0)

# %%
# (0.601, 1917000.0)
# Train accuracy 1.0000 | Validation accuracy 0.5800 | Test accuracy 0.6010
lr = LogisticRegression(penalty = 'l2', C = params[i], random_state = 0, solver='lbfgs', multi_class='multinomial', max_iter=1e5)
lr.fit(train_features, train_labels)
    
train_acc = lr.score(train_features, train_labels) # Your code here
val_acc =  lr.score(val_features, val_labels) # Your code here
test_acc = lr.score(test_features, test_labels)  # Your code here

print('Train accuracy {:.4f} | Validation accuracy {:.4f} | Test accuracy {:.4f}'.format(train_acc, val_acc, test_acc))
# Out:
# Train accuracy 1.0000 | Validation accuracy 0.5833 | Test accuracy 0.5940

# %% [markdown]
# #### Question 17: Handcrafted graph filters
#
# That's not a bad start! Now, let's try to improve a bit the results by taking into account the graph structure using tools from GSP. For this purpose, we will design a handcrafted filter that will be used to denoise the signal, before feeding it to a logistic regression.
#
# However, before we start, what hypothesis can you make on the spectral properties of the denoised signal?

# %% [markdown]
# <div class="alert alert-info">
#     <b>ANSWER</b>
# </div>

# %% [markdown]
# Based on this prior, design an ideal filter response that you believe could enhance important features of the graph.
#
# **Note:** you just need to design one graph filter that we will apply to all features. Don't design a different filter for each feature.
#
# **Note:** finding the right filter can be very challenging, don't worry if you can't find it. Just make sure you experiment with a few configurations and parameters.

# %%
# Store your spectral response here
ideal_filter = np.ones(lam.shape)#((n_nodes,))
ideal_filter[lam >= 0.1] = 0

# %% [markdown]
# <div class="alert alert-danger">
#     <b>DO: still finetune this ideal filter</b>
# </div>

# %% [markdown]
# Choose a filter order to approximate your filter using laplacian polynomials.

# %%
order = 20 # Your code here

coeff = fit_polynomial(lam, order, ideal_filter).real
graph_filter = polynomial_graph_filter(coeff, laplacian)
# Out:
# /home/jelena/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   """

# %% [markdown]
# Let's plot the frequency response of your spectral template and its polynomial approximation.

# %%
plt.plot(lam, ideal_filter)
plt.plot(lam, polynomial_graph_filter_response(coeff, lam))
plt.legend(['Ideal', 'Polynomial'])
plt.xlabel('$\lambda$')
plt.ylabel('Spectral response')
# Out:
# Text(0, 0.5, 'Spectral response')

# %% [markdown]
# Now, let's create the new features.

# %%
filtered_features = graph_filter @ features.numpy()

train_features = filtered_features[train_mask,:]
train_labels = labels[train_mask]

val_features = filtered_features[val_mask,:]
val_labels = labels[val_mask]

test_features = filtered_features[test_mask,:]
test_labels = labels[test_mask]

# %% [markdown]
# Train another logistic regression classifier on the new features. Remember to play with the regularization parameters to achieve a well performing model.

# %%
# Your code here
# Fit a logistic regression model
# Your code here
from sklearn.metrics import accuracy_score
# 8e6
C_param_range = [0.001,0.01,0.1,1,10,100, 1000, 5000, 1e4, 1e6, 8e6, 9e6, 1e7, 2e7,1e8]

try:
    C_param_range = C_param_range   #np.arange(1e6, 1e8, 1e3)
    accuracies_train = []
    accuracies_val   = []
    params = []

    j = 0
    for i in C_param_range:

        # Apply logistic regression model to training data
        lr = LogisticRegression(penalty = 'l2', C = i, random_state = 0, solver='lbfgs', multi_class='multinomial', max_iter=1e5)

        # Predict using model
        y_pred_train = lr.fit(train_features, train_labels).predict(test_features)
        y_pred_val   = lr.fit(val_features, val_labels).predict(test_features)

        # Calculate accuracy
        acc_train = accuracy_score(test_labels, y_pred_train)
        acc_val   = accuracy_score(test_labels, y_pred_val)
        
        # Collect
        accuracies_train.append(acc_train)
        accuracies_val.append(acc_val)
        params.append(i)

except KeyboardInterrupt:
    pass
finally:
    plt.figure(figsize=(10,7))
    plt.plot(params, accuracies_train, label="train")
    plt.plot(params, accuracies_val, label="val")
    plt.legend()
    print(max(accuracies_train), max(accuracies_val))
# Out:
# 0.824 0.822

# %%
accuracies_mean = [ (t+v)/2 for (t, v) in zip(accuracies_train, accuracies_val)]
i = (np.argmax(accuracies_mean))
accuracies_mean[i], params[i]
# Out:
# (0.823, 1000)

# %% [markdown]
# Evaluate your model.

# %%
lr = LogisticRegression(penalty = 'l2', C = params[i], random_state = 0, solver='lbfgs', multi_class='multinomial', max_iter=1e5)
lr.fit(train_features, train_labels)

train_acc = lr.score(train_features, train_labels) # Your code here
val_acc =  lr.score(val_features, val_labels) # Your code here
test_acc = lr.score(test_features, test_labels)  # Your code here

print('Train accuracy {:.4f} | Validation accuracy {:.4f} | Test accuracy {:.4f}'.format(train_acc, val_acc, test_acc))
# Out:
# Train accuracy 0.8643 | Validation accuracy 0.8233 | Test accuracy 0.8240

# %% [markdown]
# #### Question 18: Graph convolutional networks
#
# By now, you will probably have seen that it is challenging to find the right combination of spectral response, filter parameters and regularization method. And in most cases, this is a painstaking job. Wouldn't it be great to automate these tasks?
#
# Fortunately, this is possible if we use the right tools! Specifically, we will see that Graph Convolutional Networks are a great framework to automatize the feature extraction method.
#
# In this exercise, we will follow the same classification pipeline as above, but instead of hand-crafting our filter we will let `PyTorch` find the coefficients for us using gradient descent.
#
# In this section, most of the code is already written. Try to understand it and to play with some parameters. It may be useful if you want to solve some learning task in your project.
#
# We start by constructing a `LaplacianPolynomial` model in `DGL`. It computes the function: $f(X) = \sum_{i=1}^{k} \alpha_i L^i X \theta$ where the trainable parameters are the coefficients $\alpha_i$ and the matrix $\theta$. This function can be interpreted as a filtering of $X$ by $\sum_{i=1}^{k} \alpha_i L^i$ followed by a linear layer.

# %%
class LaplacianPolynomial(nn.Module):
    def __init__(self,
                 in_feats: int,
                 out_feats: int,
                 k: int,
                 dropout_prob: float,
                 norm=True):
        super().__init__()
        self._in_feats = in_feats
        self._out_feats = out_feats
        self._k = k
        self._norm = norm
        # Contains the weights learned by the Laplacian polynomial
        self.pol_weights = nn.Parameter(torch.Tensor(self._k + 1))
        # Contains the weights learned by the logistic regression (without bias)
        self.logr_weights = nn.Parameter(torch.Tensor(in_feats, out_feats))
        self.dropout = nn.Dropout(p=dropout_prob)
        self.reset_parameters()

    def reset_parameters(self):
        """Reinitialize learnable parameters."""
        torch.manual_seed(0)
        torch.nn.init.xavier_uniform_(self.logr_weights, gain=0.01)
        torch.nn.init.normal_(self.pol_weights, mean=0.0, std=1e-3)

    def forward(self, graph, feat):
        r"""Compute graph convolution.

        Notes
        -----
        * Input shape: :math:`(N, *, \text{in_feats})` where * means any number of additional
          dimensions, :math:`N` is the number of nodes.
        * Output shape: :math:`(N, *, \text{out_feats})` where all but the last dimension are
          the same shape as the input.

        Parameters
        ----------
        graph (DGLGraph) : The graph.
        feat (torch.Tensor): The input feature

        Returns
        -------
        (torch.Tensor) The output feature
        """
        feat = self.dropout(feat)
        graph = graph.local_var()
        
        # D^(-1/2)
        norm = torch.pow(graph.in_degrees().float().clamp(min=1), -0.5)
        shp = norm.shape + (1,) * (feat.dim() - 1)
        norm = torch.reshape(norm, shp)

        # mult W first to reduce the feature size for aggregation.
        feat = torch.matmul(feat, self.logr_weights)

        result = self.pol_weights[0] * feat.clone()

        for i in range(1, self._k + 1):
            old_feat = feat.clone()
            if self._norm:
                feat = feat * norm
            graph.ndata['h'] = feat
            # Feat is not modified in place
            graph.update_all(fn.copy_src(src='h', out='m'),
                             fn.sum(msg='m', out='h'))
            if self._norm:
                graph.ndata['h'] = graph.ndata['h'] * norm

            feat = old_feat - graph.ndata['h']
            result += self.pol_weights[i] * feat

        return result

    def extra_repr(self):
        """Set the extra representation of the module,
        which will come into effect when printing the model.
        """
        summary = 'in={_in_feats}, out={_out_feats}'
        summary += ', normalization={_norm}'
        return summary.format(**self.__dict__)

# %% [markdown]
# Once we have are model ready we just need to create a function that performs one step of our training loop, and another one that evaluates our model.

# %%
def train(model, g, features, labels, loss_fcn, train_mask, optimizer):
    model.train()  # Activate dropout
    
    logits = model(g, features)
    loss = loss_fcn(logits[train_mask], labels[train_mask])

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    return loss

def evaluate(model, g, features, labels, mask):
    model.eval()  # Deactivate dropout
    with torch.no_grad():
        logits = model(g, features)[mask]  # only compute the evaluation set
        labels = labels[mask]
        _, indices = torch.max(logits, dim=1)
        correct = torch.sum(indices == labels)
        return correct.item() * 1.0 / len(labels)

# %% [markdown]
# Choose the training parameters.

# %%
pol_order = 3
lr = 0.2
weight_decay = 5e-6
n_epochs = 1000
p_dropout = 0.8

# %% [markdown]
# And train the classifier end to end.

# %%
graph = DGLGraph(cora.graph)

model = LaplacianPolynomial(in_feats, n_classes, pol_order, p_dropout)

loss_fcn = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(),
                             lr=lr,
                             weight_decay=weight_decay)

dur = []
for epoch in range(n_epochs):
    if epoch >= 3:
        t0 = time.time()
    loss = train(model, graph, features, labels, loss_fcn, train_mask, optimizer)

    if epoch >= 3:
        dur.append(time.time() - t0)

    acc = evaluate(model, graph, features, labels, val_mask)
    print("Epoch {:05d} | Time(s) {:.4f} | Train Loss {:.4f} | Val Accuracy {:.4f}". format(
            epoch, np.mean(dur), loss.item(), acc))

print()
acc = evaluate(model, graph, features, labels, test_mask)
print("Test Accuracy {:.4f}".format(acc))
# Out:
# /home/jelena/.local/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/jelena/.local/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Epoch 00000 | Time(s) nan | Train Loss 1.9459 | Val Accuracy 0.2667
# Epoch 00001 | Time(s) nan | Train Loss 1.9221 | Val Accuracy 0.2533
# Epoch 00002 | Time(s) nan | Train Loss 1.8533 | Val Accuracy 0.2467
# Epoch 00003 | Time(s) 0.0153 | Train Loss 1.7058 | Val Accuracy 0.2700
# Epoch 00004 | Time(s) 0.0170 | Train Loss 1.4878 | Val Accuracy 0.2900
# Epoch 00005 | Time(s) 0.0166 | Train Loss 1.3438 | Val Accuracy 0.2967
# Epoch 00006 | Time(s) 0.0163 | Train Loss 1.0504 | Val Accuracy 0.3067
# Epoch 00007 | Time(s) 0.0162 | Train Loss 1.1285 | Val Accuracy 0.3167
# Epoch 00008 | Time(s) 0.0160 | Train Loss 0.8329 | Val Accuracy 0.3200
# Epoch 00009 | Time(s) 0.0159 | Train Loss 0.9067 | Val Accuracy 0.3167
# Epoch 00010 | Time(s) 0.0158 | Train Loss 0.8401 | Val Accuracy 0.3133
# Epoch 00011 | Time(s) 0.0176 | Train Loss 1.0514 | Val Accuracy 0.3133
# Epoch 00012 | Time(s) 0.0193 | Train Loss 1.1378 | Val Accuracy 0.3300
# Epoch 00013 | Time(s) 0.0192 | Train Loss 1.1666 | Val Accuracy 0.3200
# Epoch 00014 | Time(s) 0.0189 | Train Loss 0.8151 | Val Accuracy 0.3167
# Epoch 00015 | Time(s) 0.0186 | Train Loss 0.8316 | Val Accuracy 0.3167
# Epoch 00016 | Time(s) 0.0184 | Train Loss 0.8922 | Val Accuracy 0.3167
# Epoch 00017 | Time(s) 0.0182 | Train Loss 0.7648 | Val Accuracy 0.3200
# Epoch 00018 | Time(s) 0.0181 | Train Loss 0.7275 | Val Accuracy 0.3200
# Epoch 00019 | Time(s) 0.0194 | Train Loss 0.9363 | Val Accuracy 0.3300
# Epoch 00020 | Time(s) 0.0193 | Train Loss 0.7085 | Val Accuracy 0.3233
# Epoch 00021 | Time(s) 0.0195 | Train Loss 0.7683 | Val Accuracy 0.3200
# Epoch 00022 | Time(s) 0.0193 | Train Loss 0.7049 | Val Accuracy 0.3300
# Epoch 00023 | Time(s) 0.0192 | Train Loss 0.7990 | Val Accuracy 0.3300
# Epoch 00024 | Time(s) 0.0190 | Train Loss 0.7614 | Val Accuracy 0.3433
# Epoch 00025 | Time(s) 0.0189 | Train Loss 0.7960 | Val Accuracy 0.3467
# Epoch 00026 | Time(s) 0.0188 | Train Loss 0.6679 | Val Accuracy 0.3467
# Epoch 00027 | Time(s) 0.0187 | Train Loss 0.7161 | Val Accuracy 0.3467
# Epoch 00028 | Time(s) 0.0185 | Train Loss 0.6409 | Val Accuracy 0.3533
# Epoch 00029 | Time(s) 0.0189 | Train Loss 0.6874 | Val Accuracy 0.3533
# Epoch 00030 | Time(s) 0.0189 | Train Loss 0.7622 | Val Accuracy 0.3533
# Epoch 00031 | Time(s) 0.0189 | Train Loss 0.5464 | Val Accuracy 0.3533
# Epoch 00032 | Time(s) 0.0188 | Train Loss 0.6318 | Val Accuracy 0.3533
# Epoch 00033 | Time(s) 0.0187 | Train Loss 0.6195 | Val Accuracy 0.3533
# Epoch 00034 | Time(s) 0.0186 | Train Loss 0.4815 | Val Accuracy 0.3467
# Epoch 00035 | Time(s) 0.0185 | Train Loss 0.6728 | Val Accuracy 0.3433
# Epoch 00036 | Time(s) 0.0184 | Train Loss 0.6106 | Val Accuracy 0.3400
# Epoch 00037 | Time(s) 0.0184 | Train Loss 0.6110 | Val Accuracy 0.3300
# Epoch 00038 | Time(s) 0.0183 | Train Loss 0.6327 | Val Accuracy 0.3300
# Epoch 00039 | Time(s) 0.0186 | Train Loss 0.5988 | Val Accuracy 0.3333
# Epoch 00040 | Time(s) 0.0185 | Train Loss 0.5341 | Val Accuracy 0.3333
# Epoch 00041 | Time(s) 0.0185 | Train Loss 0.4669 | Val Accuracy 0.3333
# Epoch 00042 | Time(s) 0.0188 | Train Loss 0.5973 | Val Accuracy 0.3333
# Epoch 00043 | Time(s) 0.0189 | Train Loss 0.5050 | Val Accuracy 0.3333
# Epoch 00044 | Time(s) 0.0191 | Train Loss 0.3758 | Val Accuracy 0.3367
# Epoch 00045 | Time(s) 0.0193 | Train Loss 0.3994 | Val Accuracy 0.3433
# Epoch 00046 | Time(s) 0.0197 | Train Loss 0.5454 | Val Accuracy 0.3433
# Epoch 00047 | Time(s) 0.0200 | Train Loss 0.3418 | Val Accuracy 0.3433
# Epoch 00048 | Time(s) 0.0204 | Train Loss 0.3225 | Val Accuracy 0.3400
# Epoch 00049 | Time(s) 0.0207 | Train Loss 0.4310 | Val Accuracy 0.3400
# Epoch 00050 | Time(s) 0.0207 | Train Loss 0.4654 | Val Accuracy 0.3433
# Epoch 00051 | Time(s) 0.0208 | Train Loss 0.3416 | Val Accuracy 0.3433
# Epoch 00052 | Time(s) 0.0211 | Train Loss 0.4344 | Val Accuracy 0.3433
# Epoch 00053 | Time(s) 0.0210 | Train Loss 0.3267 | Val Accuracy 0.3433
# Epoch 00054 | Time(s) 0.0209 | Train Loss 0.5606 | Val Accuracy 0.3400
# Epoch 00055 | Time(s) 0.0208 | Train Loss 0.5156 | Val Accuracy 0.3400
# Epoch 00056 | Time(s) 0.0207 | Train Loss 0.4624 | Val Accuracy 0.3433
# Epoch 00057 | Time(s) 0.0206 | Train Loss 0.4255 | Val Accuracy 0.3467
# Epoch 00058 | Time(s) 0.0206 | Train Loss 0.3553 | Val Accuracy 0.3500
# Epoch 00059 | Time(s) 0.0205 | Train Loss 0.5239 | Val Accuracy 0.3567
# Epoch 00060 | Time(s) 0.0204 | Train Loss 0.4148 | Val Accuracy 0.3567
# Epoch 00061 | Time(s) 0.0203 | Train Loss 0.4882 | Val Accuracy 0.3533
# Epoch 00062 | Time(s) 0.0202 | Train Loss 0.3427 | Val Accuracy 0.3533
# Epoch 00063 | Time(s) 0.0202 | Train Loss 0.3815 | Val Accuracy 0.3533
# Epoch 00064 | Time(s) 0.0202 | Train Loss 0.3363 | Val Accuracy 0.3567
# Epoch 00065 | Time(s) 0.0202 | Train Loss 0.3985 | Val Accuracy 0.3600
# Epoch 00066 | Time(s) 0.0201 | Train Loss 0.2889 | Val Accuracy 0.3600
# Epoch 00067 | Time(s) 0.0201 | Train Loss 0.4435 | Val Accuracy 0.3633
# Epoch 00068 | Time(s) 0.0201 | Train Loss 0.2890 | Val Accuracy 0.3700
# Epoch 00069 | Time(s) 0.0201 | Train Loss 0.4004 | Val Accuracy 0.3733
# Epoch 00070 | Time(s) 0.0201 | Train Loss 0.4397 | Val Accuracy 0.3733
# Epoch 00071 | Time(s) 0.0201 | Train Loss 0.3800 | Val Accuracy 0.3700
# Epoch 00072 | Time(s) 0.0201 | Train Loss 0.3402 | Val Accuracy 0.3767
# Epoch 00073 | Time(s) 0.0200 | Train Loss 0.2631 | Val Accuracy 0.3800
# Epoch 00074 | Time(s) 0.0200 | Train Loss 0.3356 | Val Accuracy 0.3800
# Epoch 00075 | Time(s) 0.0200 | Train Loss 0.3678 | Val Accuracy 0.3800
# Epoch 00076 | Time(s) 0.0201 | Train Loss 0.2726 | Val Accuracy 0.3967
# Epoch 00077 | Time(s) 0.0201 | Train Loss 0.3200 | Val Accuracy 0.4000
# Epoch 00078 | Time(s) 0.0202 | Train Loss 0.4084 | Val Accuracy 0.3967
# Epoch 00079 | Time(s) 0.0204 | Train Loss 0.2667 | Val Accuracy 0.3933
# Epoch 00080 | Time(s) 0.0204 | Train Loss 0.3814 | Val Accuracy 0.3967
# Epoch 00081 | Time(s) 0.0204 | Train Loss 0.2594 | Val Accuracy 0.3967
# Epoch 00082 | Time(s) 0.0203 | Train Loss 0.2875 | Val Accuracy 0.4000
# Epoch 00083 | Time(s) 0.0203 | Train Loss 0.3133 | Val Accuracy 0.3933
# Epoch 00084 | Time(s) 0.0206 | Train Loss 0.3002 | Val Accuracy 0.3900
# Epoch 00085 | Time(s) 0.0208 | Train Loss 0.3026 | Val Accuracy 0.3967
# Epoch 00086 | Time(s) 0.0209 | Train Loss 0.3240 | Val Accuracy 0.4033
# Epoch 00087 | Time(s) 0.0211 | Train Loss 0.3446 | Val Accuracy 0.4000
# Epoch 00088 | Time(s) 0.0211 | Train Loss 0.2963 | Val Accuracy 0.4000
# Epoch 00089 | Time(s) 0.0210 | Train Loss 0.2259 | Val Accuracy 0.4033
# Epoch 00090 | Time(s) 0.0211 | Train Loss 0.2313 | Val Accuracy 0.3967
# Epoch 00091 | Time(s) 0.0211 | Train Loss 0.3496 | Val Accuracy 0.3933
# Epoch 00092 | Time(s) 0.0211 | Train Loss 0.2584 | Val Accuracy 0.3900
# Epoch 00093 | Time(s) 0.0210 | Train Loss 0.2706 | Val Accuracy 0.3900
# Epoch 00094 | Time(s) 0.0210 | Train Loss 0.2953 | Val Accuracy 0.3900
# Epoch 00095 | Time(s) 0.0210 | Train Loss 0.4489 | Val Accuracy 0.3967
# Epoch 00096 | Time(s) 0.0209 | Train Loss 0.3128 | Val Accuracy 0.4167
# Epoch 00097 | Time(s) 0.0209 | Train Loss 0.2181 | Val Accuracy 0.4233
# Epoch 00098 | Time(s) 0.0208 | Train Loss 0.2781 | Val Accuracy 0.4400
# Epoch 00099 | Time(s) 0.0208 | Train Loss 0.2628 | Val Accuracy 0.4367
# Epoch 00100 | Time(s) 0.0209 | Train Loss 0.2553 | Val Accuracy 0.4467
# Epoch 00101 | Time(s) 0.0211 | Train Loss 0.2259 | Val Accuracy 0.4433
# Epoch 00102 | Time(s) 0.0211 | Train Loss 0.2217 | Val Accuracy 0.4367
# Epoch 00103 | Time(s) 0.0210 | Train Loss 0.2929 | Val Accuracy 0.4367
# Epoch 00104 | Time(s) 0.0210 | Train Loss 0.2741 | Val Accuracy 0.4433
# Epoch 00105 | Time(s) 0.0209 | Train Loss 0.3085 | Val Accuracy 0.4467
# Epoch 00106 | Time(s) 0.0209 | Train Loss 0.2734 | Val Accuracy 0.4467
# Epoch 00107 | Time(s) 0.0209 | Train Loss 0.2792 | Val Accuracy 0.4500
# Epoch 00108 | Time(s) 0.0209 | Train Loss 0.2303 | Val Accuracy 0.4567
# Epoch 00109 | Time(s) 0.0208 | Train Loss 0.1978 | Val Accuracy 0.4600
# Epoch 00110 | Time(s) 0.0208 | Train Loss 0.3651 | Val Accuracy 0.4700
# Epoch 00111 | Time(s) 0.0208 | Train Loss 0.2440 | Val Accuracy 0.4800
# Epoch 00112 | Time(s) 0.0207 | Train Loss 0.2693 | Val Accuracy 0.4800
# Epoch 00113 | Time(s) 0.0207 | Train Loss 0.2340 | Val Accuracy 0.4800
# Epoch 00114 | Time(s) 0.0207 | Train Loss 0.2812 | Val Accuracy 0.4867
# Epoch 00115 | Time(s) 0.0206 | Train Loss 0.2674 | Val Accuracy 0.4933
# Epoch 00116 | Time(s) 0.0207 | Train Loss 0.1922 | Val Accuracy 0.4933
# Epoch 00117 | Time(s) 0.0206 | Train Loss 0.2064 | Val Accuracy 0.4933
# Epoch 00118 | Time(s) 0.0206 | Train Loss 0.2180 | Val Accuracy 0.4900
# Epoch 00119 | Time(s) 0.0206 | Train Loss 0.3112 | Val Accuracy 0.4867
# Epoch 00120 | Time(s) 0.0206 | Train Loss 0.1790 | Val Accuracy 0.4767
# Epoch 00121 | Time(s) 0.0205 | Train Loss 0.1252 | Val Accuracy 0.4733
# Epoch 00122 | Time(s) 0.0205 | Train Loss 0.1799 | Val Accuracy 0.4800
# Epoch 00123 | Time(s) 0.0205 | Train Loss 0.1971 | Val Accuracy 0.4833
# Epoch 00124 | Time(s) 0.0204 | Train Loss 0.1703 | Val Accuracy 0.4833
# Epoch 00125 | Time(s) 0.0205 | Train Loss 0.1530 | Val Accuracy 0.4833
# Epoch 00126 | Time(s) 0.0205 | Train Loss 0.1862 | Val Accuracy 0.5067
# Epoch 00127 | Time(s) 0.0204 | Train Loss 0.1641 | Val Accuracy 0.5200
# Epoch 00128 | Time(s) 0.0204 | Train Loss 0.2754 | Val Accuracy 0.5233
# Epoch 00129 | Time(s) 0.0204 | Train Loss 0.2412 | Val Accuracy 0.5433
# Epoch 00130 | Time(s) 0.0203 | Train Loss 0.2384 | Val Accuracy 0.5467
# Epoch 00131 | Time(s) 0.0203 | Train Loss 0.1321 | Val Accuracy 0.5633
# Epoch 00132 | Time(s) 0.0203 | Train Loss 0.1747 | Val Accuracy 0.5467
# Epoch 00133 | Time(s) 0.0204 | Train Loss 0.1293 | Val Accuracy 0.5300
# Epoch 00134 | Time(s) 0.0203 | Train Loss 0.1605 | Val Accuracy 0.5167
# Epoch 00135 | Time(s) 0.0203 | Train Loss 0.1850 | Val Accuracy 0.5033
# Epoch 00136 | Time(s) 0.0203 | Train Loss 0.1121 | Val Accuracy 0.4967
# Epoch 00137 | Time(s) 0.0203 | Train Loss 0.2143 | Val Accuracy 0.4967
# Epoch 00138 | Time(s) 0.0203 | Train Loss 0.2201 | Val Accuracy 0.5033
# Epoch 00139 | Time(s) 0.0203 | Train Loss 0.2410 | Val Accuracy 0.5167
# Epoch 00140 | Time(s) 0.0203 | Train Loss 0.1930 | Val Accuracy 0.5233
# Epoch 00141 | Time(s) 0.0202 | Train Loss 0.1996 | Val Accuracy 0.5367
# Epoch 00142 | Time(s) 0.0202 | Train Loss 0.1125 | Val Accuracy 0.5533
# Epoch 00143 | Time(s) 0.0202 | Train Loss 0.1798 | Val Accuracy 0.5767
# Epoch 00144 | Time(s) 0.0202 | Train Loss 0.1353 | Val Accuracy 0.5833
# Epoch 00145 | Time(s) 0.0202 | Train Loss 0.2692 | Val Accuracy 0.5833
# Epoch 00146 | Time(s) 0.0202 | Train Loss 0.1590 | Val Accuracy 0.5800
# Epoch 00147 | Time(s) 0.0202 | Train Loss 0.1583 | Val Accuracy 0.5700
# Epoch 00148 | Time(s) 0.0202 | Train Loss 0.1758 | Val Accuracy 0.5500
# Epoch 00149 | Time(s) 0.0202 | Train Loss 0.1695 | Val Accuracy 0.5433
# Epoch 00150 | Time(s) 0.0202 | Train Loss 0.0978 | Val Accuracy 0.5367
# Epoch 00151 | Time(s) 0.0202 | Train Loss 0.1717 | Val Accuracy 0.5300
# Epoch 00152 | Time(s) 0.0202 | Train Loss 0.1541 | Val Accuracy 0.5400
# Epoch 00153 | Time(s) 0.0202 | Train Loss 0.0948 | Val Accuracy 0.5533
# Epoch 00154 | Time(s) 0.0202 | Train Loss 0.1603 | Val Accuracy 0.5600
# Epoch 00155 | Time(s) 0.0201 | Train Loss 0.1102 | Val Accuracy 0.5700
# Epoch 00156 | Time(s) 0.0201 | Train Loss 0.1169 | Val Accuracy 0.5867
# Epoch 00157 | Time(s) 0.0201 | Train Loss 0.1266 | Val Accuracy 0.6067
# Epoch 00158 | Time(s) 0.0201 | Train Loss 0.1048 | Val Accuracy 0.6133
# Epoch 00159 | Time(s) 0.0201 | Train Loss 0.1205 | Val Accuracy 0.6133
# Epoch 00160 | Time(s) 0.0200 | Train Loss 0.1548 | Val Accuracy 0.6133
# Epoch 00161 | Time(s) 0.0201 | Train Loss 0.1888 | Val Accuracy 0.6300
# Epoch 00162 | Time(s) 0.0201 | Train Loss 0.1792 | Val Accuracy 0.6467
# Epoch 00163 | Time(s) 0.0200 | Train Loss 0.1414 | Val Accuracy 0.6467
# Epoch 00164 | Time(s) 0.0200 | Train Loss 0.1374 | Val Accuracy 0.6467
# Epoch 00165 | Time(s) 0.0200 | Train Loss 0.1400 | Val Accuracy 0.6400
# Epoch 00166 | Time(s) 0.0200 | Train Loss 0.0553 | Val Accuracy 0.6367
# Epoch 00167 | Time(s) 0.0200 | Train Loss 0.0831 | Val Accuracy 0.6267
# Epoch 00168 | Time(s) 0.0199 | Train Loss 0.1537 | Val Accuracy 0.6233
# Epoch 00169 | Time(s) 0.0199 | Train Loss 0.0971 | Val Accuracy 0.6233
# Epoch 00170 | Time(s) 0.0199 | Train Loss 0.1230 | Val Accuracy 0.6233
# Epoch 00171 | Time(s) 0.0199 | Train Loss 0.1725 | Val Accuracy 0.6167
# Epoch 00172 | Time(s) 0.0199 | Train Loss 0.1725 | Val Accuracy 0.6367
# Epoch 00173 | Time(s) 0.0199 | Train Loss 0.1242 | Val Accuracy 0.6467
# Epoch 00174 | Time(s) 0.0199 | Train Loss 0.1305 | Val Accuracy 0.6600
# Epoch 00175 | Time(s) 0.0199 | Train Loss 0.0918 | Val Accuracy 0.6667
# Epoch 00176 | Time(s) 0.0199 | Train Loss 0.1130 | Val Accuracy 0.6700
# Epoch 00177 | Time(s) 0.0198 | Train Loss 0.1130 | Val Accuracy 0.6767
# Epoch 00178 | Time(s) 0.0198 | Train Loss 0.0965 | Val Accuracy 0.6733
# Epoch 00179 | Time(s) 0.0198 | Train Loss 0.1199 | Val Accuracy 0.6633
# Epoch 00180 | Time(s) 0.0198 | Train Loss 0.0929 | Val Accuracy 0.6600
# Epoch 00181 | Time(s) 0.0198 | Train Loss 0.0921 | Val Accuracy 0.6667
# Epoch 00182 | Time(s) 0.0198 | Train Loss 0.0308 | Val Accuracy 0.6733
# Epoch 00183 | Time(s) 0.0199 | Train Loss 0.0740 | Val Accuracy 0.6700
# Epoch 00184 | Time(s) 0.0199 | Train Loss 0.1181 | Val Accuracy 0.6700
# Epoch 00185 | Time(s) 0.0200 | Train Loss 0.0830 | Val Accuracy 0.6667
# Epoch 00186 | Time(s) 0.0201 | Train Loss 0.1247 | Val Accuracy 0.6800
# Epoch 00187 | Time(s) 0.0201 | Train Loss 0.0931 | Val Accuracy 0.6833
# Epoch 00188 | Time(s) 0.0202 | Train Loss 0.0670 | Val Accuracy 0.6900
# Epoch 00189 | Time(s) 0.0202 | Train Loss 0.0738 | Val Accuracy 0.6933
# Epoch 00190 | Time(s) 0.0202 | Train Loss 0.0672 | Val Accuracy 0.6933
# Epoch 00191 | Time(s) 0.0201 | Train Loss 0.1117 | Val Accuracy 0.6867
# Epoch 00192 | Time(s) 0.0201 | Train Loss 0.1166 | Val Accuracy 0.6900
# Epoch 00193 | Time(s) 0.0201 | Train Loss 0.1055 | Val Accuracy 0.6933
# Epoch 00194 | Time(s) 0.0201 | Train Loss 0.1552 | Val Accuracy 0.6933
# Epoch 00195 | Time(s) 0.0201 | Train Loss 0.0720 | Val Accuracy 0.7000
# Epoch 00196 | Time(s) 0.0201 | Train Loss 0.0540 | Val Accuracy 0.7033
# Epoch 00197 | Time(s) 0.0201 | Train Loss 0.1594 | Val Accuracy 0.7033
# Epoch 00198 | Time(s) 0.0200 | Train Loss 0.1094 | Val Accuracy 0.6967
# Epoch 00199 | Time(s) 0.0200 | Train Loss 0.1150 | Val Accuracy 0.6933
# Epoch 00200 | Time(s) 0.0200 | Train Loss 0.0666 | Val Accuracy 0.6933
# Epoch 00201 | Time(s) 0.0200 | Train Loss 0.0890 | Val Accuracy 0.6967
# Epoch 00202 | Time(s) 0.0200 | Train Loss 0.1232 | Val Accuracy 0.7000
# Epoch 00203 | Time(s) 0.0199 | Train Loss 0.1002 | Val Accuracy 0.6967
# Epoch 00204 | Time(s) 0.0199 | Train Loss 0.1411 | Val Accuracy 0.7000
# Epoch 00205 | Time(s) 0.0200 | Train Loss 0.0743 | Val Accuracy 0.7000
# Epoch 00206 | Time(s) 0.0200 | Train Loss 0.0868 | Val Accuracy 0.7067
# Epoch 00207 | Time(s) 0.0199 | Train Loss 0.0697 | Val Accuracy 0.7067
# Epoch 00208 | Time(s) 0.0199 | Train Loss 0.1170 | Val Accuracy 0.7067
# Epoch 00209 | Time(s) 0.0199 | Train Loss 0.0784 | Val Accuracy 0.7067
# Epoch 00210 | Time(s) 0.0199 | Train Loss 0.1013 | Val Accuracy 0.7000
# Epoch 00211 | Time(s) 0.0199 | Train Loss 0.1855 | Val Accuracy 0.7033
# Epoch 00212 | Time(s) 0.0198 | Train Loss 0.0809 | Val Accuracy 0.7000
# Epoch 00213 | Time(s) 0.0198 | Train Loss 0.0695 | Val Accuracy 0.7000
# Epoch 00214 | Time(s) 0.0198 | Train Loss 0.1139 | Val Accuracy 0.7067
# Epoch 00215 | Time(s) 0.0198 | Train Loss 0.0884 | Val Accuracy 0.7067
# Epoch 00216 | Time(s) 0.0198 | Train Loss 0.1466 | Val Accuracy 0.7067
# Epoch 00217 | Time(s) 0.0198 | Train Loss 0.0456 | Val Accuracy 0.7067
# Epoch 00218 | Time(s) 0.0198 | Train Loss 0.0444 | Val Accuracy 0.7033
# Epoch 00219 | Time(s) 0.0198 | Train Loss 0.0623 | Val Accuracy 0.7067
# Epoch 00220 | Time(s) 0.0198 | Train Loss 0.0988 | Val Accuracy 0.7133
# Epoch 00221 | Time(s) 0.0197 | Train Loss 0.0691 | Val Accuracy 0.7200
# Epoch 00222 | Time(s) 0.0197 | Train Loss 0.0909 | Val Accuracy 0.7167
# Epoch 00223 | Time(s) 0.0197 | Train Loss 0.0908 | Val Accuracy 0.7200
# Epoch 00224 | Time(s) 0.0197 | Train Loss 0.1029 | Val Accuracy 0.7233
# Epoch 00225 | Time(s) 0.0197 | Train Loss 0.0547 | Val Accuracy 0.7233
# Epoch 00226 | Time(s) 0.0197 | Train Loss 0.0729 | Val Accuracy 0.7200
# Epoch 00227 | Time(s) 0.0197 | Train Loss 0.0882 | Val Accuracy 0.7200
# Epoch 00228 | Time(s) 0.0197 | Train Loss 0.0692 | Val Accuracy 0.7200
# Epoch 00229 | Time(s) 0.0197 | Train Loss 0.0895 | Val Accuracy 0.7200
# Epoch 00230 | Time(s) 0.0197 | Train Loss 0.0578 | Val Accuracy 0.7233
# Epoch 00231 | Time(s) 0.0196 | Train Loss 0.1002 | Val Accuracy 0.7200
# Epoch 00232 | Time(s) 0.0196 | Train Loss 0.0860 | Val Accuracy 0.7167
# Epoch 00233 | Time(s) 0.0196 | Train Loss 0.0423 | Val Accuracy 0.7133
# Epoch 00234 | Time(s) 0.0196 | Train Loss 0.1385 | Val Accuracy 0.7200
# Epoch 00235 | Time(s) 0.0196 | Train Loss 0.1209 | Val Accuracy 0.7233
# Epoch 00236 | Time(s) 0.0196 | Train Loss 0.0649 | Val Accuracy 0.7267
# Epoch 00237 | Time(s) 0.0196 | Train Loss 0.0521 | Val Accuracy 0.7233
# Epoch 00238 | Time(s) 0.0195 | Train Loss 0.0492 | Val Accuracy 0.7233
# Epoch 00239 | Time(s) 0.0195 | Train Loss 0.0792 | Val Accuracy 0.7233
# Epoch 00240 | Time(s) 0.0195 | Train Loss 0.0556 | Val Accuracy 0.7233
# Epoch 00241 | Time(s) 0.0195 | Train Loss 0.0382 | Val Accuracy 0.7200
# Epoch 00242 | Time(s) 0.0195 | Train Loss 0.0947 | Val Accuracy 0.7200
# Epoch 00243 | Time(s) 0.0195 | Train Loss 0.0524 | Val Accuracy 0.7267
# Epoch 00244 | Time(s) 0.0195 | Train Loss 0.0449 | Val Accuracy 0.7200
# Epoch 00245 | Time(s) 0.0195 | Train Loss 0.0579 | Val Accuracy 0.7200
# Epoch 00246 | Time(s) 0.0195 | Train Loss 0.1111 | Val Accuracy 0.7200
# Epoch 00247 | Time(s) 0.0195 | Train Loss 0.0614 | Val Accuracy 0.7200
# Epoch 00248 | Time(s) 0.0194 | Train Loss 0.1068 | Val Accuracy 0.7233
# Epoch 00249 | Time(s) 0.0194 | Train Loss 0.0222 | Val Accuracy 0.7233
# Epoch 00250 | Time(s) 0.0194 | Train Loss 0.1009 | Val Accuracy 0.7267
# Epoch 00251 | Time(s) 0.0194 | Train Loss 0.0750 | Val Accuracy 0.7300
# Epoch 00252 | Time(s) 0.0194 | Train Loss 0.0860 | Val Accuracy 0.7300
# Epoch 00253 | Time(s) 0.0194 | Train Loss 0.0453 | Val Accuracy 0.7267
# Epoch 00254 | Time(s) 0.0194 | Train Loss 0.0765 | Val Accuracy 0.7333
# Epoch 00255 | Time(s) 0.0194 | Train Loss 0.0535 | Val Accuracy 0.7300
# Epoch 00256 | Time(s) 0.0194 | Train Loss 0.0808 | Val Accuracy 0.7300
# Epoch 00257 | Time(s) 0.0194 | Train Loss 0.0988 | Val Accuracy 0.7267
# Epoch 00258 | Time(s) 0.0195 | Train Loss 0.0651 | Val Accuracy 0.7200
# Epoch 00259 | Time(s) 0.0195 | Train Loss 0.0450 | Val Accuracy 0.7133
# Epoch 00260 | Time(s) 0.0194 | Train Loss 0.0628 | Val Accuracy 0.7200
# Epoch 00261 | Time(s) 0.0194 | Train Loss 0.0754 | Val Accuracy 0.7233
# Epoch 00262 | Time(s) 0.0194 | Train Loss 0.0456 | Val Accuracy 0.7267
# Epoch 00263 | Time(s) 0.0194 | Train Loss 0.0334 | Val Accuracy 0.7300
# Epoch 00264 | Time(s) 0.0194 | Train Loss 0.0360 | Val Accuracy 0.7333
# Epoch 00265 | Time(s) 0.0194 | Train Loss 0.0703 | Val Accuracy 0.7400
# Epoch 00266 | Time(s) 0.0194 | Train Loss 0.0280 | Val Accuracy 0.7433
# Epoch 00267 | Time(s) 0.0194 | Train Loss 0.0815 | Val Accuracy 0.7467
# Epoch 00268 | Time(s) 0.0194 | Train Loss 0.0284 | Val Accuracy 0.7467
# Epoch 00269 | Time(s) 0.0194 | Train Loss 0.0599 | Val Accuracy 0.7533
# Epoch 00270 | Time(s) 0.0194 | Train Loss 0.0465 | Val Accuracy 0.7567
# Epoch 00271 | Time(s) 0.0193 | Train Loss 0.0612 | Val Accuracy 0.7567
# Epoch 00272 | Time(s) 0.0193 | Train Loss 0.0833 | Val Accuracy 0.7500
# Epoch 00273 | Time(s) 0.0194 | Train Loss 0.0509 | Val Accuracy 0.7433
# Epoch 00274 | Time(s) 0.0194 | Train Loss 0.0620 | Val Accuracy 0.7433
# Epoch 00275 | Time(s) 0.0194 | Train Loss 0.0516 | Val Accuracy 0.7433
# Epoch 00276 | Time(s) 0.0193 | Train Loss 0.0651 | Val Accuracy 0.7367
# Epoch 00277 | Time(s) 0.0193 | Train Loss 0.0477 | Val Accuracy 0.7367
# Epoch 00278 | Time(s) 0.0193 | Train Loss 0.0753 | Val Accuracy 0.7300
# Epoch 00279 | Time(s) 0.0193 | Train Loss 0.0578 | Val Accuracy 0.7300
# Epoch 00280 | Time(s) 0.0193 | Train Loss 0.0619 | Val Accuracy 0.7333
# Epoch 00281 | Time(s) 0.0193 | Train Loss 0.0320 | Val Accuracy 0.7333
# Epoch 00282 | Time(s) 0.0193 | Train Loss 0.0338 | Val Accuracy 0.7367
# Epoch 00283 | Time(s) 0.0193 | Train Loss 0.0455 | Val Accuracy 0.7333
# Epoch 00284 | Time(s) 0.0193 | Train Loss 0.0532 | Val Accuracy 0.7300
# Epoch 00285 | Time(s) 0.0193 | Train Loss 0.0553 | Val Accuracy 0.7300
# Epoch 00286 | Time(s) 0.0193 | Train Loss 0.0807 | Val Accuracy 0.7233
# Epoch 00287 | Time(s) 0.0193 | Train Loss 0.0969 | Val Accuracy 0.7233
# Epoch 00288 | Time(s) 0.0193 | Train Loss 0.0645 | Val Accuracy 0.7300
# Epoch 00289 | Time(s) 0.0193 | Train Loss 0.0313 | Val Accuracy 0.7333
# Epoch 00290 | Time(s) 0.0193 | Train Loss 0.0529 | Val Accuracy 0.7433
# Epoch 00291 | Time(s) 0.0193 | Train Loss 0.0514 | Val Accuracy 0.7500
# Epoch 00292 | Time(s) 0.0193 | Train Loss 0.0531 | Val Accuracy 0.7500
# Epoch 00293 | Time(s) 0.0193 | Train Loss 0.0442 | Val Accuracy 0.7533
# Epoch 00294 | Time(s) 0.0192 | Train Loss 0.0854 | Val Accuracy 0.7533
# Epoch 00295 | Time(s) 0.0192 | Train Loss 0.1049 | Val Accuracy 0.7633
# Epoch 00296 | Time(s) 0.0192 | Train Loss 0.0693 | Val Accuracy 0.7533
# Epoch 00297 | Time(s) 0.0192 | Train Loss 0.1049 | Val Accuracy 0.7400
# Epoch 00298 | Time(s) 0.0192 | Train Loss 0.0257 | Val Accuracy 0.7200
# Epoch 00299 | Time(s) 0.0192 | Train Loss 0.0874 | Val Accuracy 0.7167
# Epoch 00300 | Time(s) 0.0192 | Train Loss 0.0697 | Val Accuracy 0.7167
# Epoch 00301 | Time(s) 0.0192 | Train Loss 0.0739 | Val Accuracy 0.7133
# Epoch 00302 | Time(s) 0.0192 | Train Loss 0.0417 | Val Accuracy 0.7133
# Epoch 00303 | Time(s) 0.0192 | Train Loss 0.0431 | Val Accuracy 0.7100
# Epoch 00304 | Time(s) 0.0192 | Train Loss 0.0855 | Val Accuracy 0.7167
# Epoch 00305 | Time(s) 0.0192 | Train Loss 0.0712 | Val Accuracy 0.7300
# Epoch 00306 | Time(s) 0.0192 | Train Loss 0.0978 | Val Accuracy 0.7500
# Epoch 00307 | Time(s) 0.0192 | Train Loss 0.0397 | Val Accuracy 0.7533
# Epoch 00308 | Time(s) 0.0192 | Train Loss 0.0421 | Val Accuracy 0.7567
# Epoch 00309 | Time(s) 0.0191 | Train Loss 0.0381 | Val Accuracy 0.7600
# Epoch 00310 | Time(s) 0.0191 | Train Loss 0.0733 | Val Accuracy 0.7633
# Epoch 00311 | Time(s) 0.0191 | Train Loss 0.0416 | Val Accuracy 0.7633
# Epoch 00312 | Time(s) 0.0191 | Train Loss 0.0651 | Val Accuracy 0.7633
# Epoch 00313 | Time(s) 0.0191 | Train Loss 0.0426 | Val Accuracy 0.7600
# Epoch 00314 | Time(s) 0.0191 | Train Loss 0.0584 | Val Accuracy 0.7600
# Epoch 00315 | Time(s) 0.0191 | Train Loss 0.0598 | Val Accuracy 0.7600
# Epoch 00316 | Time(s) 0.0191 | Train Loss 0.0627 | Val Accuracy 0.7633
# Epoch 00317 | Time(s) 0.0191 | Train Loss 0.0562 | Val Accuracy 0.7767
# Epoch 00318 | Time(s) 0.0191 | Train Loss 0.0626 | Val Accuracy 0.7733
# Epoch 00319 | Time(s) 0.0191 | Train Loss 0.0747 | Val Accuracy 0.7767
# Epoch 00320 | Time(s) 0.0191 | Train Loss 0.0472 | Val Accuracy 0.7800
# Epoch 00321 | Time(s) 0.0191 | Train Loss 0.0500 | Val Accuracy 0.7767
# Epoch 00322 | Time(s) 0.0191 | Train Loss 0.0675 | Val Accuracy 0.7800
# Epoch 00323 | Time(s) 0.0191 | Train Loss 0.0385 | Val Accuracy 0.7800
# Epoch 00324 | Time(s) 0.0191 | Train Loss 0.0663 | Val Accuracy 0.7800
# Epoch 00325 | Time(s) 0.0191 | Train Loss 0.0879 | Val Accuracy 0.7800
# Epoch 00326 | Time(s) 0.0191 | Train Loss 0.0477 | Val Accuracy 0.7800
# Epoch 00327 | Time(s) 0.0191 | Train Loss 0.0375 | Val Accuracy 0.7800
# Epoch 00328 | Time(s) 0.0191 | Train Loss 0.0833 | Val Accuracy 0.7800
# Epoch 00329 | Time(s) 0.0190 | Train Loss 0.0379 | Val Accuracy 0.7800
# Epoch 00330 | Time(s) 0.0190 | Train Loss 0.0273 | Val Accuracy 0.7700
# Epoch 00331 | Time(s) 0.0190 | Train Loss 0.1315 | Val Accuracy 0.7767
# Epoch 00332 | Time(s) 0.0190 | Train Loss 0.0487 | Val Accuracy 0.7767
# Epoch 00333 | Time(s) 0.0190 | Train Loss 0.0602 | Val Accuracy 0.7733
# Epoch 00334 | Time(s) 0.0190 | Train Loss 0.0372 | Val Accuracy 0.7700
# Epoch 00335 | Time(s) 0.0190 | Train Loss 0.0985 | Val Accuracy 0.7667
# Epoch 00336 | Time(s) 0.0190 | Train Loss 0.0779 | Val Accuracy 0.7700
# Epoch 00337 | Time(s) 0.0190 | Train Loss 0.0870 | Val Accuracy 0.7700
# Epoch 00338 | Time(s) 0.0190 | Train Loss 0.0535 | Val Accuracy 0.7700
# Epoch 00339 | Time(s) 0.0190 | Train Loss 0.0361 | Val Accuracy 0.7700
# Epoch 00340 | Time(s) 0.0190 | Train Loss 0.0129 | Val Accuracy 0.7733
# Epoch 00341 | Time(s) 0.0190 | Train Loss 0.0954 | Val Accuracy 0.7700
# Epoch 00342 | Time(s) 0.0190 | Train Loss 0.0672 | Val Accuracy 0.7700
# Epoch 00343 | Time(s) 0.0190 | Train Loss 0.0573 | Val Accuracy 0.7667
# Epoch 00344 | Time(s) 0.0190 | Train Loss 0.0653 | Val Accuracy 0.7633
# Epoch 00345 | Time(s) 0.0190 | Train Loss 0.0327 | Val Accuracy 0.7633
# Epoch 00346 | Time(s) 0.0189 | Train Loss 0.0426 | Val Accuracy 0.7667
# Epoch 00347 | Time(s) 0.0190 | Train Loss 0.0411 | Val Accuracy 0.7567
# Epoch 00348 | Time(s) 0.0190 | Train Loss 0.0716 | Val Accuracy 0.7600
# Epoch 00349 | Time(s) 0.0190 | Train Loss 0.0396 | Val Accuracy 0.7600
# Epoch 00350 | Time(s) 0.0189 | Train Loss 0.0397 | Val Accuracy 0.7567
# Epoch 00351 | Time(s) 0.0189 | Train Loss 0.0282 | Val Accuracy 0.7567
# Epoch 00352 | Time(s) 0.0189 | Train Loss 0.0781 | Val Accuracy 0.7533
# Epoch 00353 | Time(s) 0.0189 | Train Loss 0.0456 | Val Accuracy 0.7533
# Epoch 00354 | Time(s) 0.0189 | Train Loss 0.0419 | Val Accuracy 0.7567
# Epoch 00355 | Time(s) 0.0189 | Train Loss 0.0921 | Val Accuracy 0.7533
# Epoch 00356 | Time(s) 0.0189 | Train Loss 0.0557 | Val Accuracy 0.7533
# Epoch 00357 | Time(s) 0.0189 | Train Loss 0.0482 | Val Accuracy 0.7567
# Epoch 00358 | Time(s) 0.0189 | Train Loss 0.0400 | Val Accuracy 0.7567
# Epoch 00359 | Time(s) 0.0189 | Train Loss 0.0522 | Val Accuracy 0.7567
# Epoch 00360 | Time(s) 0.0189 | Train Loss 0.0915 | Val Accuracy 0.7633
# Epoch 00361 | Time(s) 0.0189 | Train Loss 0.0809 | Val Accuracy 0.7667
# Epoch 00362 | Time(s) 0.0189 | Train Loss 0.0685 | Val Accuracy 0.7700
# Epoch 00363 | Time(s) 0.0189 | Train Loss 0.0412 | Val Accuracy 0.7733
# Epoch 00364 | Time(s) 0.0189 | Train Loss 0.0600 | Val Accuracy 0.7800
# Epoch 00365 | Time(s) 0.0189 | Train Loss 0.0816 | Val Accuracy 0.7767
# Epoch 00366 | Time(s) 0.0189 | Train Loss 0.0722 | Val Accuracy 0.7733
# Epoch 00367 | Time(s) 0.0189 | Train Loss 0.0978 | Val Accuracy 0.7733
# Epoch 00368 | Time(s) 0.0189 | Train Loss 0.0363 | Val Accuracy 0.7733
# Epoch 00369 | Time(s) 0.0189 | Train Loss 0.0350 | Val Accuracy 0.7733
# Epoch 00370 | Time(s) 0.0189 | Train Loss 0.0577 | Val Accuracy 0.7667
# Epoch 00371 | Time(s) 0.0190 | Train Loss 0.0490 | Val Accuracy 0.7633
# Epoch 00372 | Time(s) 0.0189 | Train Loss 0.1220 | Val Accuracy 0.7667
# Epoch 00373 | Time(s) 0.0189 | Train Loss 0.0696 | Val Accuracy 0.7533
# Epoch 00374 | Time(s) 0.0189 | Train Loss 0.0723 | Val Accuracy 0.7533
# Epoch 00375 | Time(s) 0.0189 | Train Loss 0.1220 | Val Accuracy 0.7567
# Epoch 00376 | Time(s) 0.0189 | Train Loss 0.0374 | Val Accuracy 0.7567
# Epoch 00377 | Time(s) 0.0189 | Train Loss 0.0702 | Val Accuracy 0.7533
# Epoch 00378 | Time(s) 0.0189 | Train Loss 0.0928 | Val Accuracy 0.7533
# Epoch 00379 | Time(s) 0.0189 | Train Loss 0.0523 | Val Accuracy 0.7500
# Epoch 00380 | Time(s) 0.0189 | Train Loss 0.0710 | Val Accuracy 0.7500
# Epoch 00381 | Time(s) 0.0189 | Train Loss 0.0704 | Val Accuracy 0.7500
# Epoch 00382 | Time(s) 0.0189 | Train Loss 0.0577 | Val Accuracy 0.7500
# Epoch 00383 | Time(s) 0.0189 | Train Loss 0.0707 | Val Accuracy 0.7633
# Epoch 00384 | Time(s) 0.0189 | Train Loss 0.0580 | Val Accuracy 0.7667
# Epoch 00385 | Time(s) 0.0189 | Train Loss 0.0677 | Val Accuracy 0.7700
# Epoch 00386 | Time(s) 0.0189 | Train Loss 0.0571 | Val Accuracy 0.7700
# Epoch 00387 | Time(s) 0.0188 | Train Loss 0.0343 | Val Accuracy 0.7767
# Epoch 00388 | Time(s) 0.0188 | Train Loss 0.0491 | Val Accuracy 0.7800
# Epoch 00389 | Time(s) 0.0189 | Train Loss 0.0302 | Val Accuracy 0.7733
# Epoch 00390 | Time(s) 0.0188 | Train Loss 0.1066 | Val Accuracy 0.7800
# Epoch 00391 | Time(s) 0.0188 | Train Loss 0.0370 | Val Accuracy 0.7833
# Epoch 00392 | Time(s) 0.0188 | Train Loss 0.0258 | Val Accuracy 0.7800
# Epoch 00393 | Time(s) 0.0188 | Train Loss 0.0304 | Val Accuracy 0.7800
# Epoch 00394 | Time(s) 0.0188 | Train Loss 0.0883 | Val Accuracy 0.7767
# Epoch 00395 | Time(s) 0.0188 | Train Loss 0.0449 | Val Accuracy 0.7733
# Epoch 00396 | Time(s) 0.0188 | Train Loss 0.0405 | Val Accuracy 0.7733
# Epoch 00397 | Time(s) 0.0188 | Train Loss 0.0417 | Val Accuracy 0.7733
# Epoch 00398 | Time(s) 0.0188 | Train Loss 0.0853 | Val Accuracy 0.7733
# Epoch 00399 | Time(s) 0.0188 | Train Loss 0.0634 | Val Accuracy 0.7733
# Epoch 00400 | Time(s) 0.0188 | Train Loss 0.0567 | Val Accuracy 0.7733
# Epoch 00401 | Time(s) 0.0188 | Train Loss 0.0451 | Val Accuracy 0.7733
# Epoch 00402 | Time(s) 0.0188 | Train Loss 0.0627 | Val Accuracy 0.7700
# Epoch 00403 | Time(s) 0.0188 | Train Loss 0.0781 | Val Accuracy 0.7767
# Epoch 00404 | Time(s) 0.0188 | Train Loss 0.0794 | Val Accuracy 0.7733
# Epoch 00405 | Time(s) 0.0188 | Train Loss 0.0382 | Val Accuracy 0.7733
# Epoch 00406 | Time(s) 0.0188 | Train Loss 0.0408 | Val Accuracy 0.7733
# Epoch 00407 | Time(s) 0.0188 | Train Loss 0.0422 | Val Accuracy 0.7733
# Epoch 00408 | Time(s) 0.0188 | Train Loss 0.0603 | Val Accuracy 0.7733
# Epoch 00409 | Time(s) 0.0188 | Train Loss 0.0489 | Val Accuracy 0.7767
# Epoch 00410 | Time(s) 0.0188 | Train Loss 0.0255 | Val Accuracy 0.7733
# Epoch 00411 | Time(s) 0.0188 | Train Loss 0.0266 | Val Accuracy 0.7733
# Epoch 00412 | Time(s) 0.0188 | Train Loss 0.0429 | Val Accuracy 0.7733
# Epoch 00413 | Time(s) 0.0188 | Train Loss 0.1291 | Val Accuracy 0.7700
# Epoch 00414 | Time(s) 0.0188 | Train Loss 0.0266 | Val Accuracy 0.7633
# Epoch 00415 | Time(s) 0.0187 | Train Loss 0.0582 | Val Accuracy 0.7600
# Epoch 00416 | Time(s) 0.0187 | Train Loss 0.0096 | Val Accuracy 0.7633
# Epoch 00417 | Time(s) 0.0187 | Train Loss 0.0227 | Val Accuracy 0.7600
# Epoch 00418 | Time(s) 0.0187 | Train Loss 0.0324 | Val Accuracy 0.7600
# Epoch 00419 | Time(s) 0.0188 | Train Loss 0.0796 | Val Accuracy 0.7600
# Epoch 00420 | Time(s) 0.0188 | Train Loss 0.0434 | Val Accuracy 0.7567
# Epoch 00421 | Time(s) 0.0187 | Train Loss 0.0274 | Val Accuracy 0.7600
# Epoch 00422 | Time(s) 0.0187 | Train Loss 0.0459 | Val Accuracy 0.7633
# Epoch 00423 | Time(s) 0.0187 | Train Loss 0.0315 | Val Accuracy 0.7633
# Epoch 00424 | Time(s) 0.0187 | Train Loss 0.0309 | Val Accuracy 0.7633
# Epoch 00425 | Time(s) 0.0187 | Train Loss 0.0399 | Val Accuracy 0.7633
# Epoch 00426 | Time(s) 0.0187 | Train Loss 0.0855 | Val Accuracy 0.7700
# Epoch 00427 | Time(s) 0.0187 | Train Loss 0.0463 | Val Accuracy 0.7733
# Epoch 00428 | Time(s) 0.0187 | Train Loss 0.0285 | Val Accuracy 0.7733
# Epoch 00429 | Time(s) 0.0187 | Train Loss 0.0451 | Val Accuracy 0.7767
# Epoch 00430 | Time(s) 0.0187 | Train Loss 0.0338 | Val Accuracy 0.7800
# Epoch 00431 | Time(s) 0.0187 | Train Loss 0.1237 | Val Accuracy 0.7767
# Epoch 00432 | Time(s) 0.0187 | Train Loss 0.0688 | Val Accuracy 0.7800
# Epoch 00433 | Time(s) 0.0187 | Train Loss 0.0292 | Val Accuracy 0.7833
# Epoch 00434 | Time(s) 0.0187 | Train Loss 0.0913 | Val Accuracy 0.7900
# Epoch 00435 | Time(s) 0.0187 | Train Loss 0.0336 | Val Accuracy 0.7900
# Epoch 00436 | Time(s) 0.0187 | Train Loss 0.0393 | Val Accuracy 0.7967
# Epoch 00437 | Time(s) 0.0187 | Train Loss 0.0595 | Val Accuracy 0.8000
# Epoch 00438 | Time(s) 0.0187 | Train Loss 0.0331 | Val Accuracy 0.8033
# Epoch 00439 | Time(s) 0.0187 | Train Loss 0.0742 | Val Accuracy 0.8033
# Epoch 00440 | Time(s) 0.0187 | Train Loss 0.0435 | Val Accuracy 0.8033
# Epoch 00441 | Time(s) 0.0187 | Train Loss 0.0136 | Val Accuracy 0.7967
# Epoch 00442 | Time(s) 0.0187 | Train Loss 0.0597 | Val Accuracy 0.7867
# Epoch 00443 | Time(s) 0.0187 | Train Loss 0.0464 | Val Accuracy 0.7867
# Epoch 00444 | Time(s) 0.0187 | Train Loss 0.0227 | Val Accuracy 0.7833
# Epoch 00445 | Time(s) 0.0187 | Train Loss 0.0521 | Val Accuracy 0.7767
# Epoch 00446 | Time(s) 0.0187 | Train Loss 0.0325 | Val Accuracy 0.7800
# Epoch 00447 | Time(s) 0.0187 | Train Loss 0.0876 | Val Accuracy 0.7767
# Epoch 00448 | Time(s) 0.0187 | Train Loss 0.0608 | Val Accuracy 0.7767
# Epoch 00449 | Time(s) 0.0187 | Train Loss 0.0738 | Val Accuracy 0.7767
# Epoch 00450 | Time(s) 0.0187 | Train Loss 0.0419 | Val Accuracy 0.7767
# Epoch 00451 | Time(s) 0.0187 | Train Loss 0.0605 | Val Accuracy 0.7767
# Epoch 00452 | Time(s) 0.0187 | Train Loss 0.0589 | Val Accuracy 0.7767
# Epoch 00453 | Time(s) 0.0187 | Train Loss 0.0240 | Val Accuracy 0.7800
# Epoch 00454 | Time(s) 0.0187 | Train Loss 0.0280 | Val Accuracy 0.7767
# Epoch 00455 | Time(s) 0.0187 | Train Loss 0.0855 | Val Accuracy 0.7800
# Epoch 00456 | Time(s) 0.0187 | Train Loss 0.0893 | Val Accuracy 0.7767
# Epoch 00457 | Time(s) 0.0187 | Train Loss 0.0710 | Val Accuracy 0.7700
# Epoch 00458 | Time(s) 0.0187 | Train Loss 0.0473 | Val Accuracy 0.7700
# Epoch 00459 | Time(s) 0.0187 | Train Loss 0.0330 | Val Accuracy 0.7667
# Epoch 00460 | Time(s) 0.0187 | Train Loss 0.0229 | Val Accuracy 0.7667
# Epoch 00461 | Time(s) 0.0187 | Train Loss 0.0770 | Val Accuracy 0.7633
# Epoch 00462 | Time(s) 0.0187 | Train Loss 0.0744 | Val Accuracy 0.7633
# Epoch 00463 | Time(s) 0.0187 | Train Loss 0.0994 | Val Accuracy 0.7667
# Epoch 00464 | Time(s) 0.0187 | Train Loss 0.0204 | Val Accuracy 0.7700
# Epoch 00465 | Time(s) 0.0187 | Train Loss 0.0381 | Val Accuracy 0.7767
# Epoch 00466 | Time(s) 0.0187 | Train Loss 0.0450 | Val Accuracy 0.7733
# Epoch 00467 | Time(s) 0.0187 | Train Loss 0.0421 | Val Accuracy 0.7767
# Epoch 00468 | Time(s) 0.0187 | Train Loss 0.0372 | Val Accuracy 0.7667
# Epoch 00469 | Time(s) 0.0187 | Train Loss 0.0545 | Val Accuracy 0.7667
# Epoch 00470 | Time(s) 0.0187 | Train Loss 0.0559 | Val Accuracy 0.7700
# Epoch 00471 | Time(s) 0.0187 | Train Loss 0.0704 | Val Accuracy 0.7667
# Epoch 00472 | Time(s) 0.0187 | Train Loss 0.1044 | Val Accuracy 0.7733
# Epoch 00473 | Time(s) 0.0187 | Train Loss 0.0616 | Val Accuracy 0.7767
# Epoch 00474 | Time(s) 0.0187 | Train Loss 0.0263 | Val Accuracy 0.7767
# Epoch 00475 | Time(s) 0.0187 | Train Loss 0.0242 | Val Accuracy 0.7733
# Epoch 00476 | Time(s) 0.0187 | Train Loss 0.0159 | Val Accuracy 0.7733
# Epoch 00477 | Time(s) 0.0187 | Train Loss 0.0958 | Val Accuracy 0.7767
# Epoch 00478 | Time(s) 0.0187 | Train Loss 0.0501 | Val Accuracy 0.7733
# Epoch 00479 | Time(s) 0.0187 | Train Loss 0.0856 | Val Accuracy 0.7700
# Epoch 00480 | Time(s) 0.0187 | Train Loss 0.0278 | Val Accuracy 0.7733
# Epoch 00481 | Time(s) 0.0187 | Train Loss 0.0358 | Val Accuracy 0.7700
# Epoch 00482 | Time(s) 0.0187 | Train Loss 0.0268 | Val Accuracy 0.7733
# Epoch 00483 | Time(s) 0.0187 | Train Loss 0.0680 | Val Accuracy 0.7733
# Epoch 00484 | Time(s) 0.0187 | Train Loss 0.0861 | Val Accuracy 0.7700
# Epoch 00485 | Time(s) 0.0187 | Train Loss 0.0654 | Val Accuracy 0.7733
# Epoch 00486 | Time(s) 0.0187 | Train Loss 0.0529 | Val Accuracy 0.7767
# Epoch 00487 | Time(s) 0.0187 | Train Loss 0.0508 | Val Accuracy 0.7767
# Epoch 00488 | Time(s) 0.0187 | Train Loss 0.0361 | Val Accuracy 0.7733
# Epoch 00489 | Time(s) 0.0187 | Train Loss 0.0627 | Val Accuracy 0.7733
# Epoch 00490 | Time(s) 0.0187 | Train Loss 0.0225 | Val Accuracy 0.7733
# Epoch 00491 | Time(s) 0.0187 | Train Loss 0.0431 | Val Accuracy 0.7700
# Epoch 00492 | Time(s) 0.0186 | Train Loss 0.0213 | Val Accuracy 0.7667
# Epoch 00493 | Time(s) 0.0186 | Train Loss 0.0211 | Val Accuracy 0.7633
# Epoch 00494 | Time(s) 0.0186 | Train Loss 0.0507 | Val Accuracy 0.7633
# Epoch 00495 | Time(s) 0.0186 | Train Loss 0.0869 | Val Accuracy 0.7633
# Epoch 00496 | Time(s) 0.0186 | Train Loss 0.0601 | Val Accuracy 0.7667
# Epoch 00497 | Time(s) 0.0186 | Train Loss 0.0509 | Val Accuracy 0.7700
# Epoch 00498 | Time(s) 0.0186 | Train Loss 0.0534 | Val Accuracy 0.7667
# Epoch 00499 | Time(s) 0.0186 | Train Loss 0.0317 | Val Accuracy 0.7667
# Epoch 00500 | Time(s) 0.0186 | Train Loss 0.0462 | Val Accuracy 0.7667
# Epoch 00501 | Time(s) 0.0186 | Train Loss 0.0431 | Val Accuracy 0.7633
# Epoch 00502 | Time(s) 0.0187 | Train Loss 0.0214 | Val Accuracy 0.7633
# Epoch 00503 | Time(s) 0.0187 | Train Loss 0.0472 | Val Accuracy 0.7633
# Epoch 00504 | Time(s) 0.0186 | Train Loss 0.0716 | Val Accuracy 0.7733
# Epoch 00505 | Time(s) 0.0187 | Train Loss 0.0277 | Val Accuracy 0.7800
# Epoch 00506 | Time(s) 0.0187 | Train Loss 0.0351 | Val Accuracy 0.7833
# Epoch 00507 | Time(s) 0.0187 | Train Loss 0.0133 | Val Accuracy 0.7867
# Epoch 00508 | Time(s) 0.0186 | Train Loss 0.0355 | Val Accuracy 0.7900
# Epoch 00509 | Time(s) 0.0186 | Train Loss 0.0362 | Val Accuracy 0.7900
# Epoch 00510 | Time(s) 0.0186 | Train Loss 0.0599 | Val Accuracy 0.8000
# Epoch 00511 | Time(s) 0.0186 | Train Loss 0.0764 | Val Accuracy 0.8000
# Epoch 00512 | Time(s) 0.0186 | Train Loss 0.0389 | Val Accuracy 0.8000
# Epoch 00513 | Time(s) 0.0186 | Train Loss 0.0137 | Val Accuracy 0.8033
# Epoch 00514 | Time(s) 0.0186 | Train Loss 0.0226 | Val Accuracy 0.8000
# Epoch 00515 | Time(s) 0.0186 | Train Loss 0.0396 | Val Accuracy 0.7967
# Epoch 00516 | Time(s) 0.0186 | Train Loss 0.0218 | Val Accuracy 0.7933
# Epoch 00517 | Time(s) 0.0186 | Train Loss 0.0312 | Val Accuracy 0.7933
# Epoch 00518 | Time(s) 0.0186 | Train Loss 0.0333 | Val Accuracy 0.8000
# Epoch 00519 | Time(s) 0.0186 | Train Loss 0.0575 | Val Accuracy 0.7933
# Epoch 00520 | Time(s) 0.0186 | Train Loss 0.0314 | Val Accuracy 0.7933
# Epoch 00521 | Time(s) 0.0186 | Train Loss 0.0488 | Val Accuracy 0.7867
# Epoch 00522 | Time(s) 0.0186 | Train Loss 0.0547 | Val Accuracy 0.7867
# Epoch 00523 | Time(s) 0.0186 | Train Loss 0.0817 | Val Accuracy 0.7767
# Epoch 00524 | Time(s) 0.0186 | Train Loss 0.0291 | Val Accuracy 0.7733
# Epoch 00525 | Time(s) 0.0186 | Train Loss 0.0181 | Val Accuracy 0.7800
# Epoch 00526 | Time(s) 0.0186 | Train Loss 0.0298 | Val Accuracy 0.7800
# Epoch 00527 | Time(s) 0.0186 | Train Loss 0.0572 | Val Accuracy 0.7767
# Epoch 00528 | Time(s) 0.0186 | Train Loss 0.0508 | Val Accuracy 0.7767
# Epoch 00529 | Time(s) 0.0186 | Train Loss 0.0233 | Val Accuracy 0.7733
# Epoch 00530 | Time(s) 0.0186 | Train Loss 0.0189 | Val Accuracy 0.7733
# Epoch 00531 | Time(s) 0.0186 | Train Loss 0.0465 | Val Accuracy 0.7733
# Epoch 00532 | Time(s) 0.0186 | Train Loss 0.0376 | Val Accuracy 0.7733
# Epoch 00533 | Time(s) 0.0186 | Train Loss 0.0378 | Val Accuracy 0.7700
# Epoch 00534 | Time(s) 0.0186 | Train Loss 0.0338 | Val Accuracy 0.7700
# Epoch 00535 | Time(s) 0.0186 | Train Loss 0.0167 | Val Accuracy 0.7667
# Epoch 00536 | Time(s) 0.0186 | Train Loss 0.0265 | Val Accuracy 0.7700
# Epoch 00537 | Time(s) 0.0186 | Train Loss 0.0350 | Val Accuracy 0.7633
# Epoch 00538 | Time(s) 0.0186 | Train Loss 0.0407 | Val Accuracy 0.7633
# Epoch 00539 | Time(s) 0.0186 | Train Loss 0.0125 | Val Accuracy 0.7667
# Epoch 00540 | Time(s) 0.0186 | Train Loss 0.0733 | Val Accuracy 0.7633
# Epoch 00541 | Time(s) 0.0186 | Train Loss 0.0337 | Val Accuracy 0.7667
# Epoch 00542 | Time(s) 0.0186 | Train Loss 0.0192 | Val Accuracy 0.7667
# Epoch 00543 | Time(s) 0.0186 | Train Loss 0.0341 | Val Accuracy 0.7667
# Epoch 00544 | Time(s) 0.0186 | Train Loss 0.0805 | Val Accuracy 0.7700
# Epoch 00545 | Time(s) 0.0186 | Train Loss 0.0346 | Val Accuracy 0.7733
# Epoch 00546 | Time(s) 0.0186 | Train Loss 0.0261 | Val Accuracy 0.7800
# Epoch 00547 | Time(s) 0.0186 | Train Loss 0.0261 | Val Accuracy 0.7800
# Epoch 00548 | Time(s) 0.0186 | Train Loss 0.0353 | Val Accuracy 0.7900
# Epoch 00549 | Time(s) 0.0186 | Train Loss 0.0210 | Val Accuracy 0.7900
# Epoch 00550 | Time(s) 0.0186 | Train Loss 0.0360 | Val Accuracy 0.7933
# Epoch 00551 | Time(s) 0.0186 | Train Loss 0.0476 | Val Accuracy 0.7967
# Epoch 00552 | Time(s) 0.0186 | Train Loss 0.0283 | Val Accuracy 0.7900
# Epoch 00553 | Time(s) 0.0186 | Train Loss 0.0456 | Val Accuracy 0.7933
# Epoch 00554 | Time(s) 0.0186 | Train Loss 0.0232 | Val Accuracy 0.7933
# Epoch 00555 | Time(s) 0.0186 | Train Loss 0.0397 | Val Accuracy 0.7833
# Epoch 00556 | Time(s) 0.0186 | Train Loss 0.0317 | Val Accuracy 0.7933
# Epoch 00557 | Time(s) 0.0186 | Train Loss 0.0324 | Val Accuracy 0.7867
# Epoch 00558 | Time(s) 0.0186 | Train Loss 0.0930 | Val Accuracy 0.7800
# Epoch 00559 | Time(s) 0.0186 | Train Loss 0.0144 | Val Accuracy 0.7767
# Epoch 00560 | Time(s) 0.0186 | Train Loss 0.0638 | Val Accuracy 0.7733
# Epoch 00561 | Time(s) 0.0186 | Train Loss 0.0327 | Val Accuracy 0.7733
# Epoch 00562 | Time(s) 0.0186 | Train Loss 0.0353 | Val Accuracy 0.7733
# Epoch 00563 | Time(s) 0.0186 | Train Loss 0.0139 | Val Accuracy 0.7700
# Epoch 00564 | Time(s) 0.0186 | Train Loss 0.0261 | Val Accuracy 0.7667
# Epoch 00565 | Time(s) 0.0186 | Train Loss 0.0430 | Val Accuracy 0.7667
# Epoch 00566 | Time(s) 0.0186 | Train Loss 0.0485 | Val Accuracy 0.7633
# Epoch 00567 | Time(s) 0.0186 | Train Loss 0.0812 | Val Accuracy 0.7600
# Epoch 00568 | Time(s) 0.0186 | Train Loss 0.0268 | Val Accuracy 0.7633
# Epoch 00569 | Time(s) 0.0186 | Train Loss 0.0837 | Val Accuracy 0.7633
# Epoch 00570 | Time(s) 0.0186 | Train Loss 0.1128 | Val Accuracy 0.7600
# Epoch 00571 | Time(s) 0.0186 | Train Loss 0.0200 | Val Accuracy 0.7600
# Epoch 00572 | Time(s) 0.0186 | Train Loss 0.0740 | Val Accuracy 0.7567
# Epoch 00573 | Time(s) 0.0186 | Train Loss 0.0085 | Val Accuracy 0.7567
# Epoch 00574 | Time(s) 0.0186 | Train Loss 0.0126 | Val Accuracy 0.7567
# Epoch 00575 | Time(s) 0.0186 | Train Loss 0.0587 | Val Accuracy 0.7633
# Epoch 00576 | Time(s) 0.0186 | Train Loss 0.0635 | Val Accuracy 0.7700
# Epoch 00577 | Time(s) 0.0186 | Train Loss 0.0260 | Val Accuracy 0.7700
# Epoch 00578 | Time(s) 0.0186 | Train Loss 0.0917 | Val Accuracy 0.7700
# Epoch 00579 | Time(s) 0.0186 | Train Loss 0.0433 | Val Accuracy 0.7667
# Epoch 00580 | Time(s) 0.0186 | Train Loss 0.0572 | Val Accuracy 0.7667
# Epoch 00581 | Time(s) 0.0186 | Train Loss 0.0162 | Val Accuracy 0.7667
# Epoch 00582 | Time(s) 0.0186 | Train Loss 0.0307 | Val Accuracy 0.7800
# Epoch 00583 | Time(s) 0.0186 | Train Loss 0.0268 | Val Accuracy 0.7800
# Epoch 00584 | Time(s) 0.0186 | Train Loss 0.0415 | Val Accuracy 0.7800
# Epoch 00585 | Time(s) 0.0186 | Train Loss 0.0260 | Val Accuracy 0.7800
# Epoch 00586 | Time(s) 0.0186 | Train Loss 0.0390 | Val Accuracy 0.7800
# Epoch 00587 | Time(s) 0.0186 | Train Loss 0.0544 | Val Accuracy 0.7800
# Epoch 00588 | Time(s) 0.0186 | Train Loss 0.0237 | Val Accuracy 0.7767
# Epoch 00589 | Time(s) 0.0186 | Train Loss 0.0349 | Val Accuracy 0.7767
# Epoch 00590 | Time(s) 0.0186 | Train Loss 0.0094 | Val Accuracy 0.7733
# Epoch 00591 | Time(s) 0.0186 | Train Loss 0.0127 | Val Accuracy 0.7733
# Epoch 00592 | Time(s) 0.0186 | Train Loss 0.0377 | Val Accuracy 0.7700
# Epoch 00593 | Time(s) 0.0186 | Train Loss 0.0613 | Val Accuracy 0.7767
# Epoch 00594 | Time(s) 0.0186 | Train Loss 0.0508 | Val Accuracy 0.7833
# Epoch 00595 | Time(s) 0.0186 | Train Loss 0.0421 | Val Accuracy 0.7800
# Epoch 00596 | Time(s) 0.0186 | Train Loss 0.0409 | Val Accuracy 0.7767
# Epoch 00597 | Time(s) 0.0186 | Train Loss 0.0126 | Val Accuracy 0.7800
# Epoch 00598 | Time(s) 0.0186 | Train Loss 0.0488 | Val Accuracy 0.7833
# Epoch 00599 | Time(s) 0.0186 | Train Loss 0.0238 | Val Accuracy 0.7867
# Epoch 00600 | Time(s) 0.0186 | Train Loss 0.0429 | Val Accuracy 0.7867
# Epoch 00601 | Time(s) 0.0186 | Train Loss 0.0262 | Val Accuracy 0.7867
# Epoch 00602 | Time(s) 0.0186 | Train Loss 0.0146 | Val Accuracy 0.7900
# Epoch 00603 | Time(s) 0.0186 | Train Loss 0.0431 | Val Accuracy 0.7900
# Epoch 00604 | Time(s) 0.0186 | Train Loss 0.0254 | Val Accuracy 0.7967
# Epoch 00605 | Time(s) 0.0186 | Train Loss 0.0893 | Val Accuracy 0.7933
# Epoch 00606 | Time(s) 0.0186 | Train Loss 0.0055 | Val Accuracy 0.8000
# Epoch 00607 | Time(s) 0.0186 | Train Loss 0.0687 | Val Accuracy 0.8000
# Epoch 00608 | Time(s) 0.0186 | Train Loss 0.0683 | Val Accuracy 0.8067
# Epoch 00609 | Time(s) 0.0186 | Train Loss 0.0226 | Val Accuracy 0.8000
# Epoch 00610 | Time(s) 0.0186 | Train Loss 0.0396 | Val Accuracy 0.8000
# Epoch 00611 | Time(s) 0.0186 | Train Loss 0.0451 | Val Accuracy 0.7967
# Epoch 00612 | Time(s) 0.0186 | Train Loss 0.0119 | Val Accuracy 0.7933
# Epoch 00613 | Time(s) 0.0186 | Train Loss 0.0399 | Val Accuracy 0.7933
# Epoch 00614 | Time(s) 0.0186 | Train Loss 0.0349 | Val Accuracy 0.7933
# Epoch 00615 | Time(s) 0.0186 | Train Loss 0.0446 | Val Accuracy 0.7867
# Epoch 00616 | Time(s) 0.0186 | Train Loss 0.0532 | Val Accuracy 0.7867
# Epoch 00617 | Time(s) 0.0186 | Train Loss 0.0339 | Val Accuracy 0.7867
# Epoch 00618 | Time(s) 0.0186 | Train Loss 0.0627 | Val Accuracy 0.7867
# Epoch 00619 | Time(s) 0.0186 | Train Loss 0.0201 | Val Accuracy 0.7833
# Epoch 00620 | Time(s) 0.0186 | Train Loss 0.0456 | Val Accuracy 0.7867
# Epoch 00621 | Time(s) 0.0186 | Train Loss 0.0473 | Val Accuracy 0.7867
# Epoch 00622 | Time(s) 0.0186 | Train Loss 0.0164 | Val Accuracy 0.7900
# Epoch 00623 | Time(s) 0.0186 | Train Loss 0.0317 | Val Accuracy 0.7933
# Epoch 00624 | Time(s) 0.0185 | Train Loss 0.0619 | Val Accuracy 0.7933
# Epoch 00625 | Time(s) 0.0185 | Train Loss 0.0376 | Val Accuracy 0.7967
# Epoch 00626 | Time(s) 0.0185 | Train Loss 0.0669 | Val Accuracy 0.7967
# Epoch 00627 | Time(s) 0.0185 | Train Loss 0.0129 | Val Accuracy 0.8000
# Epoch 00628 | Time(s) 0.0185 | Train Loss 0.0250 | Val Accuracy 0.8067
# Epoch 00629 | Time(s) 0.0185 | Train Loss 0.0644 | Val Accuracy 0.8067
# Epoch 00630 | Time(s) 0.0185 | Train Loss 0.0836 | Val Accuracy 0.8133
# Epoch 00631 | Time(s) 0.0185 | Train Loss 0.0651 | Val Accuracy 0.8233
# Epoch 00632 | Time(s) 0.0185 | Train Loss 0.0379 | Val Accuracy 0.8167
# Epoch 00633 | Time(s) 0.0185 | Train Loss 0.0946 | Val Accuracy 0.8167
# Epoch 00634 | Time(s) 0.0185 | Train Loss 0.0760 | Val Accuracy 0.8167
# Epoch 00635 | Time(s) 0.0185 | Train Loss 0.0358 | Val Accuracy 0.8133
# Epoch 00636 | Time(s) 0.0185 | Train Loss 0.0401 | Val Accuracy 0.8033
# Epoch 00637 | Time(s) 0.0185 | Train Loss 0.0478 | Val Accuracy 0.7967
# Epoch 00638 | Time(s) 0.0185 | Train Loss 0.0265 | Val Accuracy 0.8000
# Epoch 00639 | Time(s) 0.0185 | Train Loss 0.0244 | Val Accuracy 0.7967
# Epoch 00640 | Time(s) 0.0185 | Train Loss 0.0276 | Val Accuracy 0.7967
# Epoch 00641 | Time(s) 0.0185 | Train Loss 0.0194 | Val Accuracy 0.7967
# Epoch 00642 | Time(s) 0.0185 | Train Loss 0.0164 | Val Accuracy 0.8000
# Epoch 00643 | Time(s) 0.0185 | Train Loss 0.0533 | Val Accuracy 0.8000
# Epoch 00644 | Time(s) 0.0185 | Train Loss 0.0274 | Val Accuracy 0.7967
# Epoch 00645 | Time(s) 0.0185 | Train Loss 0.0592 | Val Accuracy 0.7967
# Epoch 00646 | Time(s) 0.0185 | Train Loss 0.0329 | Val Accuracy 0.8033
# Epoch 00647 | Time(s) 0.0185 | Train Loss 0.0271 | Val Accuracy 0.7967
# Epoch 00648 | Time(s) 0.0185 | Train Loss 0.0552 | Val Accuracy 0.7967
# Epoch 00649 | Time(s) 0.0185 | Train Loss 0.0220 | Val Accuracy 0.8000
# Epoch 00650 | Time(s) 0.0185 | Train Loss 0.0911 | Val Accuracy 0.7933
# Epoch 00651 | Time(s) 0.0185 | Train Loss 0.0455 | Val Accuracy 0.8067
# Epoch 00652 | Time(s) 0.0185 | Train Loss 0.1064 | Val Accuracy 0.8133
# Epoch 00653 | Time(s) 0.0185 | Train Loss 0.0344 | Val Accuracy 0.8100
# Epoch 00654 | Time(s) 0.0185 | Train Loss 0.1392 | Val Accuracy 0.8100
# Epoch 00655 | Time(s) 0.0185 | Train Loss 0.0950 | Val Accuracy 0.8133
# Epoch 00656 | Time(s) 0.0185 | Train Loss 0.0133 | Val Accuracy 0.8133
# Epoch 00657 | Time(s) 0.0185 | Train Loss 0.0794 | Val Accuracy 0.8100
# Epoch 00658 | Time(s) 0.0185 | Train Loss 0.0833 | Val Accuracy 0.8033
# Epoch 00659 | Time(s) 0.0185 | Train Loss 0.0949 | Val Accuracy 0.7933
# Epoch 00660 | Time(s) 0.0185 | Train Loss 0.0424 | Val Accuracy 0.7900
# Epoch 00661 | Time(s) 0.0185 | Train Loss 0.0321 | Val Accuracy 0.7933
# Epoch 00662 | Time(s) 0.0185 | Train Loss 0.0408 | Val Accuracy 0.7833
# Epoch 00663 | Time(s) 0.0185 | Train Loss 0.0328 | Val Accuracy 0.7767
# Epoch 00664 | Time(s) 0.0185 | Train Loss 0.0801 | Val Accuracy 0.7767
# Epoch 00665 | Time(s) 0.0185 | Train Loss 0.1009 | Val Accuracy 0.7733
# Epoch 00666 | Time(s) 0.0185 | Train Loss 0.0382 | Val Accuracy 0.7733
# Epoch 00667 | Time(s) 0.0185 | Train Loss 0.0486 | Val Accuracy 0.7767
# Epoch 00668 | Time(s) 0.0185 | Train Loss 0.0221 | Val Accuracy 0.7767
# Epoch 00669 | Time(s) 0.0185 | Train Loss 0.0348 | Val Accuracy 0.7867
# Epoch 00670 | Time(s) 0.0185 | Train Loss 0.1380 | Val Accuracy 0.7867
# ...
# Epoch 00775 | Time(s) 0.0186 | Train Loss 0.1609 | Val Accuracy 0.8133
# Epoch 00776 | Time(s) 0.0186 | Train Loss 0.0572 | Val Accuracy 0.8033
# Epoch 00777 | Time(s) 0.0186 | Train Loss 0.0525 | Val Accuracy 0.8000
# Epoch 00778 | Time(s) 0.0186 | Train Loss 0.0135 | Val Accuracy 0.7967
# Epoch 00779 | Time(s) 0.0186 | Train Loss 0.0924 | Val Accuracy 0.8000
# Epoch 00780 | Time(s) 0.0186 | Train Loss 0.0207 | Val Accuracy 0.7967
# Epoch 00781 | Time(s) 0.0186 | Train Loss 0.0559 | Val Accuracy 0.7933
# Epoch 00782 | Time(s) 0.0186 | Train Loss 0.0198 | Val Accuracy 0.7933
# Epoch 00783 | Time(s) 0.0186 | Train Loss 0.0595 | Val Accuracy 0.7933
# Epoch 00784 | Time(s) 0.0186 | Train Loss 0.0548 | Val Accuracy 0.7933
# Epoch 00785 | Time(s) 0.0186 | Train Loss 0.1028 | Val Accuracy 0.7933
# Epoch 00786 | Time(s) 0.0186 | Train Loss 0.0180 | Val Accuracy 0.7900
# Epoch 00787 | Time(s) 0.0186 | Train Loss 0.0410 | Val Accuracy 0.7933
# Epoch 00788 | Time(s) 0.0186 | Train Loss 0.0793 | Val Accuracy 0.7867
# Epoch 00789 | Time(s) 0.0186 | Train Loss 0.0313 | Val Accuracy 0.7900
# Epoch 00790 | Time(s) 0.0186 | Train Loss 0.0648 | Val Accuracy 0.7967
# Epoch 00791 | Time(s) 0.0186 | Train Loss 0.0160 | Val Accuracy 0.7967
# Epoch 00792 | Time(s) 0.0186 | Train Loss 0.0186 | Val Accuracy 0.7967
# Epoch 00793 | Time(s) 0.0186 | Train Loss 0.0165 | Val Accuracy 0.7933
# Epoch 00794 | Time(s) 0.0186 | Train Loss 0.0272 | Val Accuracy 0.7967
# Epoch 00795 | Time(s) 0.0186 | Train Loss 0.0811 | Val Accuracy 0.7967
# Epoch 00796 | Time(s) 0.0186 | Train Loss 0.0280 | Val Accuracy 0.8033
# Epoch 00797 | Time(s) 0.0186 | Train Loss 0.0980 | Val Accuracy 0.8033
# Epoch 00798 | Time(s) 0.0186 | Train Loss 0.1056 | Val Accuracy 0.8067
# Epoch 00799 | Time(s) 0.0186 | Train Loss 0.0127 | Val Accuracy 0.8100
# Epoch 00800 | Time(s) 0.0186 | Train Loss 0.0202 | Val Accuracy 0.8067
# Epoch 00801 | Time(s) 0.0186 | Train Loss 0.0530 | Val Accuracy 0.8100
# Epoch 00802 | Time(s) 0.0186 | Train Loss 0.0742 | Val Accuracy 0.8067
# Epoch 00803 | Time(s) 0.0186 | Train Loss 0.0355 | Val Accuracy 0.8067
# Epoch 00804 | Time(s) 0.0186 | Train Loss 0.0350 | Val Accuracy 0.8033
# Epoch 00805 | Time(s) 0.0186 | Train Loss 0.1307 | Val Accuracy 0.8067
# Epoch 00806 | Time(s) 0.0186 | Train Loss 0.0630 | Val Accuracy 0.8067
# Epoch 00807 | Time(s) 0.0186 | Train Loss 0.0629 | Val Accuracy 0.8100
# Epoch 00808 | Time(s) 0.0186 | Train Loss 0.0155 | Val Accuracy 0.8100
# Epoch 00809 | Time(s) 0.0186 | Train Loss 0.0225 | Val Accuracy 0.8000
# Epoch 00810 | Time(s) 0.0186 | Train Loss 0.0311 | Val Accuracy 0.8033
# Epoch 00811 | Time(s) 0.0186 | Train Loss 0.0445 | Val Accuracy 0.8067
# Epoch 00812 | Time(s) 0.0186 | Train Loss 0.0738 | Val Accuracy 0.8033
# Epoch 00813 | Time(s) 0.0186 | Train Loss 0.0402 | Val Accuracy 0.8033
# Epoch 00814 | Time(s) 0.0186 | Train Loss 0.1174 | Val Accuracy 0.7967
# Epoch 00815 | Time(s) 0.0186 | Train Loss 0.0432 | Val Accuracy 0.7900
# Epoch 00816 | Time(s) 0.0186 | Train Loss 0.0511 | Val Accuracy 0.7967
# Epoch 00817 | Time(s) 0.0186 | Train Loss 0.1127 | Val Accuracy 0.7900
# Epoch 00818 | Time(s) 0.0186 | Train Loss 0.0273 | Val Accuracy 0.7733
# Epoch 00819 | Time(s) 0.0186 | Train Loss 0.0409 | Val Accuracy 0.7633
# Epoch 00820 | Time(s) 0.0186 | Train Loss 0.0535 | Val Accuracy 0.7633
# Epoch 00821 | Time(s) 0.0186 | Train Loss 0.0431 | Val Accuracy 0.7633
# Epoch 00822 | Time(s) 0.0186 | Train Loss 0.0629 | Val Accuracy 0.7667
# Epoch 00823 | Time(s) 0.0186 | Train Loss 0.0616 | Val Accuracy 0.7633
# Epoch 00824 | Time(s) 0.0186 | Train Loss 0.1335 | Val Accuracy 0.7733
# Epoch 00825 | Time(s) 0.0186 | Train Loss 0.0840 | Val Accuracy 0.7733
# Epoch 00826 | Time(s) 0.0186 | Train Loss 0.0673 | Val Accuracy 0.7800
# Epoch 00827 | Time(s) 0.0186 | Train Loss 0.0555 | Val Accuracy 0.7867
# Epoch 00828 | Time(s) 0.0186 | Train Loss 0.0431 | Val Accuracy 0.7833
# Epoch 00829 | Time(s) 0.0186 | Train Loss 0.0861 | Val Accuracy 0.7967
# Epoch 00830 | Time(s) 0.0186 | Train Loss 0.0368 | Val Accuracy 0.8000
# Epoch 00831 | Time(s) 0.0186 | Train Loss 0.0564 | Val Accuracy 0.8100
# Epoch 00832 | Time(s) 0.0186 | Train Loss 0.0902 | Val Accuracy 0.8167
# Epoch 00833 | Time(s) 0.0186 | Train Loss 0.0631 | Val Accuracy 0.8067
# Epoch 00834 | Time(s) 0.0186 | Train Loss 0.0521 | Val Accuracy 0.8067
# Epoch 00835 | Time(s) 0.0186 | Train Loss 0.0270 | Val Accuracy 0.8033
# Epoch 00836 | Time(s) 0.0186 | Train Loss 0.0489 | Val Accuracy 0.8000
# Epoch 00837 | Time(s) 0.0186 | Train Loss 0.0655 | Val Accuracy 0.7967
# Epoch 00838 | Time(s) 0.0186 | Train Loss 0.0528 | Val Accuracy 0.7933
# Epoch 00839 | Time(s) 0.0186 | Train Loss 0.0948 | Val Accuracy 0.7967
# Epoch 00840 | Time(s) 0.0186 | Train Loss 0.0400 | Val Accuracy 0.8033
# Epoch 00841 | Time(s) 0.0186 | Train Loss 0.0774 | Val Accuracy 0.8100
# Epoch 00842 | Time(s) 0.0186 | Train Loss 0.0799 | Val Accuracy 0.8133
# Epoch 00843 | Time(s) 0.0186 | Train Loss 0.0890 | Val Accuracy 0.8267
# Epoch 00844 | Time(s) 0.0186 | Train Loss 0.0261 | Val Accuracy 0.8300
# Epoch 00845 | Time(s) 0.0186 | Train Loss 0.0426 | Val Accuracy 0.8233
# Epoch 00846 | Time(s) 0.0186 | Train Loss 0.0560 | Val Accuracy 0.8267
# Epoch 00847 | Time(s) 0.0186 | Train Loss 0.0553 | Val Accuracy 0.8200
# Epoch 00848 | Time(s) 0.0186 | Train Loss 0.0704 | Val Accuracy 0.8100
# Epoch 00849 | Time(s) 0.0186 | Train Loss 0.0677 | Val Accuracy 0.7967
# Epoch 00850 | Time(s) 0.0186 | Train Loss 0.0577 | Val Accuracy 0.7767
# Epoch 00851 | Time(s) 0.0186 | Train Loss 0.0109 | Val Accuracy 0.7733
# Epoch 00852 | Time(s) 0.0186 | Train Loss 0.0567 | Val Accuracy 0.7733
# Epoch 00853 | Time(s) 0.0186 | Train Loss 0.1256 | Val Accuracy 0.7700
# Epoch 00854 | Time(s) 0.0186 | Train Loss 0.0672 | Val Accuracy 0.7900
# Epoch 00855 | Time(s) 0.0186 | Train Loss 0.0978 | Val Accuracy 0.7900
# Epoch 00856 | Time(s) 0.0186 | Train Loss 0.0208 | Val Accuracy 0.7900
# Epoch 00857 | Time(s) 0.0186 | Train Loss 0.1071 | Val Accuracy 0.7933
# Epoch 00858 | Time(s) 0.0186 | Train Loss 0.0285 | Val Accuracy 0.7967
# Epoch 00859 | Time(s) 0.0186 | Train Loss 0.0761 | Val Accuracy 0.8033
# Epoch 00860 | Time(s) 0.0186 | Train Loss 0.0523 | Val Accuracy 0.8000
# Epoch 00861 | Time(s) 0.0186 | Train Loss 0.1412 | Val Accuracy 0.8000
# Epoch 00862 | Time(s) 0.0186 | Train Loss 0.0529 | Val Accuracy 0.8033
# Epoch 00863 | Time(s) 0.0186 | Train Loss 0.1436 | Val Accuracy 0.8133
# Epoch 00864 | Time(s) 0.0186 | Train Loss 0.0691 | Val Accuracy 0.8067
# Epoch 00865 | Time(s) 0.0186 | Train Loss 0.0832 | Val Accuracy 0.8033
# Epoch 00866 | Time(s) 0.0186 | Train Loss 0.0395 | Val Accuracy 0.8033
# Epoch 00867 | Time(s) 0.0186 | Train Loss 0.0139 | Val Accuracy 0.8133
# Epoch 00868 | Time(s) 0.0186 | Train Loss 0.0210 | Val Accuracy 0.8133
# Epoch 00869 | Time(s) 0.0186 | Train Loss 0.0854 | Val Accuracy 0.8033
# Epoch 00870 | Time(s) 0.0186 | Train Loss 0.0319 | Val Accuracy 0.8000
# Epoch 00871 | Time(s) 0.0186 | Train Loss 0.0745 | Val Accuracy 0.7967
# Epoch 00872 | Time(s) 0.0186 | Train Loss 0.0784 | Val Accuracy 0.7833
# Epoch 00873 | Time(s) 0.0186 | Train Loss 0.1305 | Val Accuracy 0.7867
# Epoch 00874 | Time(s) 0.0186 | Train Loss 0.1299 | Val Accuracy 0.7867
# Epoch 00875 | Time(s) 0.0186 | Train Loss 0.0527 | Val Accuracy 0.7933
# Epoch 00876 | Time(s) 0.0186 | Train Loss 0.0503 | Val Accuracy 0.8000
# Epoch 00877 | Time(s) 0.0186 | Train Loss 0.0216 | Val Accuracy 0.8000
# Epoch 00878 | Time(s) 0.0186 | Train Loss 0.0531 | Val Accuracy 0.8067
# Epoch 00879 | Time(s) 0.0186 | Train Loss 0.0772 | Val Accuracy 0.8100
# Epoch 00880 | Time(s) 0.0186 | Train Loss 0.0691 | Val Accuracy 0.8133
# Epoch 00881 | Time(s) 0.0186 | Train Loss 0.1270 | Val Accuracy 0.8133
# Epoch 00882 | Time(s) 0.0186 | Train Loss 0.0911 | Val Accuracy 0.8067
# Epoch 00883 | Time(s) 0.0186 | Train Loss 0.0570 | Val Accuracy 0.8167
# Epoch 00884 | Time(s) 0.0186 | Train Loss 0.1413 | Val Accuracy 0.8233
# Epoch 00885 | Time(s) 0.0186 | Train Loss 0.0564 | Val Accuracy 0.8200
# Epoch 00886 | Time(s) 0.0186 | Train Loss 0.0751 | Val Accuracy 0.8167
# Epoch 00887 | Time(s) 0.0186 | Train Loss 0.0535 | Val Accuracy 0.8133
# Epoch 00888 | Time(s) 0.0186 | Train Loss 0.0390 | Val Accuracy 0.8100
# Epoch 00889 | Time(s) 0.0186 | Train Loss 0.0275 | Val Accuracy 0.8033
# Epoch 00890 | Time(s) 0.0186 | Train Loss 0.0402 | Val Accuracy 0.8000
# Epoch 00891 | Time(s) 0.0186 | Train Loss 0.0411 | Val Accuracy 0.7933
# Epoch 00892 | Time(s) 0.0186 | Train Loss 0.0247 | Val Accuracy 0.7933
# Epoch 00893 | Time(s) 0.0186 | Train Loss 0.0315 | Val Accuracy 0.7900
# Epoch 00894 | Time(s) 0.0186 | Train Loss 0.0937 | Val Accuracy 0.7900
# Epoch 00895 | Time(s) 0.0186 | Train Loss 0.0584 | Val Accuracy 0.7933
# Epoch 00896 | Time(s) 0.0186 | Train Loss 0.0714 | Val Accuracy 0.7933
# Epoch 00897 | Time(s) 0.0186 | Train Loss 0.0477 | Val Accuracy 0.8000
# Epoch 00898 | Time(s) 0.0186 | Train Loss 0.0694 | Val Accuracy 0.8000
# Epoch 00899 | Time(s) 0.0186 | Train Loss 0.0337 | Val Accuracy 0.8000
# Epoch 00900 | Time(s) 0.0186 | Train Loss 0.0562 | Val Accuracy 0.8000
# Epoch 00901 | Time(s) 0.0186 | Train Loss 0.1322 | Val Accuracy 0.7967
# Epoch 00902 | Time(s) 0.0186 | Train Loss 0.0798 | Val Accuracy 0.7900
# Epoch 00903 | Time(s) 0.0186 | Train Loss 0.0231 | Val Accuracy 0.7833
# Epoch 00904 | Time(s) 0.0186 | Train Loss 0.0342 | Val Accuracy 0.7867
# Epoch 00905 | Time(s) 0.0186 | Train Loss 0.0514 | Val Accuracy 0.7900
# Epoch 00906 | Time(s) 0.0186 | Train Loss 0.0622 | Val Accuracy 0.7933
# Epoch 00907 | Time(s) 0.0186 | Train Loss 0.0415 | Val Accuracy 0.8000
# Epoch 00908 | Time(s) 0.0186 | Train Loss 0.0577 | Val Accuracy 0.7933
# Epoch 00909 | Time(s) 0.0186 | Train Loss 0.0913 | Val Accuracy 0.8067
# Epoch 00910 | Time(s) 0.0186 | Train Loss 0.0276 | Val Accuracy 0.8100
# Epoch 00911 | Time(s) 0.0186 | Train Loss 0.1154 | Val Accuracy 0.8100
# Epoch 00912 | Time(s) 0.0186 | Train Loss 0.0153 | Val Accuracy 0.8067
# Epoch 00913 | Time(s) 0.0186 | Train Loss 0.0532 | Val Accuracy 0.8067
# Epoch 00914 | Time(s) 0.0186 | Train Loss 0.0699 | Val Accuracy 0.8133
# Epoch 00915 | Time(s) 0.0186 | Train Loss 0.0863 | Val Accuracy 0.8133
# Epoch 00916 | Time(s) 0.0186 | Train Loss 0.0769 | Val Accuracy 0.8167
# Epoch 00917 | Time(s) 0.0186 | Train Loss 0.0343 | Val Accuracy 0.8133
# Epoch 00918 | Time(s) 0.0186 | Train Loss 0.0332 | Val Accuracy 0.8100
# Epoch 00919 | Time(s) 0.0185 | Train Loss 0.0391 | Val Accuracy 0.8067
# Epoch 00920 | Time(s) 0.0186 | Train Loss 0.0500 | Val Accuracy 0.8067
# Epoch 00921 | Time(s) 0.0186 | Train Loss 0.0659 | Val Accuracy 0.8033
# Epoch 00922 | Time(s) 0.0185 | Train Loss 0.0954 | Val Accuracy 0.7933
# Epoch 00923 | Time(s) 0.0185 | Train Loss 0.0805 | Val Accuracy 0.7900
# Epoch 00924 | Time(s) 0.0185 | Train Loss 0.0596 | Val Accuracy 0.7900
# Epoch 00925 | Time(s) 0.0186 | Train Loss 0.0120 | Val Accuracy 0.7933
# Epoch 00926 | Time(s) 0.0186 | Train Loss 0.0476 | Val Accuracy 0.7867
# Epoch 00927 | Time(s) 0.0186 | Train Loss 0.0237 | Val Accuracy 0.7767
# Epoch 00928 | Time(s) 0.0186 | Train Loss 0.0380 | Val Accuracy 0.7767
# Epoch 00929 | Time(s) 0.0186 | Train Loss 0.0197 | Val Accuracy 0.7833
# Epoch 00930 | Time(s) 0.0186 | Train Loss 0.0766 | Val Accuracy 0.7867
# Epoch 00931 | Time(s) 0.0186 | Train Loss 0.0475 | Val Accuracy 0.7867
# Epoch 00932 | Time(s) 0.0186 | Train Loss 0.1269 | Val Accuracy 0.7833
# Epoch 00933 | Time(s) 0.0186 | Train Loss 0.0891 | Val Accuracy 0.7867
# Epoch 00934 | Time(s) 0.0186 | Train Loss 0.0942 | Val Accuracy 0.7900
# Epoch 00935 | Time(s) 0.0186 | Train Loss 0.0720 | Val Accuracy 0.7933
# Epoch 00936 | Time(s) 0.0186 | Train Loss 0.0550 | Val Accuracy 0.7933
# Epoch 00937 | Time(s) 0.0186 | Train Loss 0.0684 | Val Accuracy 0.7900
# Epoch 00938 | Time(s) 0.0186 | Train Loss 0.0547 | Val Accuracy 0.7900
# Epoch 00939 | Time(s) 0.0186 | Train Loss 0.0982 | Val Accuracy 0.7933
# Epoch 00940 | Time(s) 0.0186 | Train Loss 0.0111 | Val Accuracy 0.7933
# Epoch 00941 | Time(s) 0.0186 | Train Loss 0.0880 | Val Accuracy 0.7933
# Epoch 00942 | Time(s) 0.0186 | Train Loss 0.0311 | Val Accuracy 0.7967
# Epoch 00943 | Time(s) 0.0186 | Train Loss 0.0484 | Val Accuracy 0.7967
# Epoch 00944 | Time(s) 0.0186 | Train Loss 0.1024 | Val Accuracy 0.7900
# Epoch 00945 | Time(s) 0.0186 | Train Loss 0.0344 | Val Accuracy 0.7900
# Epoch 00946 | Time(s) 0.0186 | Train Loss 0.0296 | Val Accuracy 0.7900
# Epoch 00947 | Time(s) 0.0186 | Train Loss 0.0996 | Val Accuracy 0.7900
# Epoch 00948 | Time(s) 0.0186 | Train Loss 0.0100 | Val Accuracy 0.7967
# Epoch 00949 | Time(s) 0.0186 | Train Loss 0.0744 | Val Accuracy 0.7967
# Epoch 00950 | Time(s) 0.0186 | Train Loss 0.0609 | Val Accuracy 0.7967
# Epoch 00951 | Time(s) 0.0186 | Train Loss 0.0347 | Val Accuracy 0.7933
# Epoch 00952 | Time(s) 0.0186 | Train Loss 0.0509 | Val Accuracy 0.7933
# Epoch 00953 | Time(s) 0.0186 | Train Loss 0.1064 | Val Accuracy 0.8000
# Epoch 00954 | Time(s) 0.0186 | Train Loss 0.0153 | Val Accuracy 0.7900
# Epoch 00955 | Time(s) 0.0185 | Train Loss 0.0571 | Val Accuracy 0.7900
# Epoch 00956 | Time(s) 0.0185 | Train Loss 0.0506 | Val Accuracy 0.7867
# Epoch 00957 | Time(s) 0.0185 | Train Loss 0.0145 | Val Accuracy 0.7867
# Epoch 00958 | Time(s) 0.0185 | Train Loss 0.0160 | Val Accuracy 0.7900
# Epoch 00959 | Time(s) 0.0186 | Train Loss 0.1180 | Val Accuracy 0.7900
# Epoch 00960 | Time(s) 0.0185 | Train Loss 0.0449 | Val Accuracy 0.7900
# Epoch 00961 | Time(s) 0.0185 | Train Loss 0.0275 | Val Accuracy 0.7867
# Epoch 00962 | Time(s) 0.0185 | Train Loss 0.0562 | Val Accuracy 0.7833
# Epoch 00963 | Time(s) 0.0185 | Train Loss 0.0440 | Val Accuracy 0.7900
# Epoch 00964 | Time(s) 0.0185 | Train Loss 0.0249 | Val Accuracy 0.7933
# Epoch 00965 | Time(s) 0.0185 | Train Loss 0.0311 | Val Accuracy 0.7933
# Epoch 00966 | Time(s) 0.0185 | Train Loss 0.0318 | Val Accuracy 0.7867
# Epoch 00967 | Time(s) 0.0185 | Train Loss 0.0635 | Val Accuracy 0.7933
# Epoch 00968 | Time(s) 0.0185 | Train Loss 0.0380 | Val Accuracy 0.8033
# Epoch 00969 | Time(s) 0.0185 | Train Loss 0.0211 | Val Accuracy 0.8033
# Epoch 00970 | Time(s) 0.0185 | Train Loss 0.0190 | Val Accuracy 0.7933
# Epoch 00971 | Time(s) 0.0185 | Train Loss 0.0258 | Val Accuracy 0.7900
# Epoch 00972 | Time(s) 0.0185 | Train Loss 0.0727 | Val Accuracy 0.7833
# Epoch 00973 | Time(s) 0.0185 | Train Loss 0.0525 | Val Accuracy 0.7800
# Epoch 00974 | Time(s) 0.0185 | Train Loss 0.0469 | Val Accuracy 0.7800
# Epoch 00975 | Time(s) 0.0185 | Train Loss 0.0376 | Val Accuracy 0.7800
# Epoch 00976 | Time(s) 0.0185 | Train Loss 0.0357 | Val Accuracy 0.7833
# Epoch 00977 | Time(s) 0.0185 | Train Loss 0.0712 | Val Accuracy 0.7900
# Epoch 00978 | Time(s) 0.0185 | Train Loss 0.0453 | Val Accuracy 0.7967
# Epoch 00979 | Time(s) 0.0185 | Train Loss 0.0500 | Val Accuracy 0.8000
# Epoch 00980 | Time(s) 0.0185 | Train Loss 0.0349 | Val Accuracy 0.8033
# Epoch 00981 | Time(s) 0.0185 | Train Loss 0.1188 | Val Accuracy 0.8067
# Epoch 00982 | Time(s) 0.0185 | Train Loss 0.0289 | Val Accuracy 0.7933
# Epoch 00983 | Time(s) 0.0185 | Train Loss 0.0664 | Val Accuracy 0.7967
# Epoch 00984 | Time(s) 0.0185 | Train Loss 0.0596 | Val Accuracy 0.7967
# Epoch 00985 | Time(s) 0.0185 | Train Loss 0.0235 | Val Accuracy 0.7967
# Epoch 00986 | Time(s) 0.0185 | Train Loss 0.0362 | Val Accuracy 0.7933
# Epoch 00987 | Time(s) 0.0185 | Train Loss 0.0340 | Val Accuracy 0.7933
# Epoch 00988 | Time(s) 0.0185 | Train Loss 0.0564 | Val Accuracy 0.7900
# Epoch 00989 | Time(s) 0.0185 | Train Loss 0.0195 | Val Accuracy 0.7833
# Epoch 00990 | Time(s) 0.0185 | Train Loss 0.0596 | Val Accuracy 0.7833
# Epoch 00991 | Time(s) 0.0185 | Train Loss 0.0367 | Val Accuracy 0.7833
# Epoch 00992 | Time(s) 0.0185 | Train Loss 0.0710 | Val Accuracy 0.7833
# Epoch 00993 | Time(s) 0.0185 | Train Loss 0.0646 | Val Accuracy 0.7867
# Epoch 00994 | Time(s) 0.0185 | Train Loss 0.0431 | Val Accuracy 0.7900
# Epoch 00995 | Time(s) 0.0186 | Train Loss 0.0656 | Val Accuracy 0.7900
# Epoch 00996 | Time(s) 0.0185 | Train Loss 0.0215 | Val Accuracy 0.7933
# Epoch 00997 | Time(s) 0.0185 | Train Loss 0.0508 | Val Accuracy 0.7833
# Epoch 00998 | Time(s) 0.0185 | Train Loss 0.0815 | Val Accuracy 0.7833
# Epoch 00999 | Time(s) 0.0185 | Train Loss 0.0073 | Val Accuracy 0.7800
#
# Test Accuracy 0.7890

# %% [markdown]
# Trained this way our GCN based on polynomials of the laplacian is a black box. Fortunately, however, the only difference between this shallow model and our previous classifier is the way we chose the filter coefficients.
#
# Let's see what the network learned.
# Print the coefficients of the learned filter.

# %%
coeff_gcn = model.pol_weights.detach().numpy() # Your code here
print(coeff_gcn)
# Out:
# [-12.9955435  16.841042   -1.9869193  -2.7977014]

# %% [markdown]
# To interpret the model we can plot the frequency response of the learned filter.

# %%
plt.semilogy(lam, np.abs(polynomial_graph_filter_response(coeff_gcn, lam)))
plt.xlabel('$\lambda$')
plt.ylabel('Spectral response (db)')
# Out:
# Text(0, 0.5, 'Spectral response (db)')

# %% [markdown]
# #### Question 19
#
# As we said, the whole classification pipeline of the previous exercise is identical to the one we tried before: Graph filtering + Logistic regression. The only difference lies in the way we chose the filter coefficients. First we were choosing them manually, and now, we let `PyTorch` find them for us. However, if everything is correct we should be able to use this filter to construct new hand-crafted features and train a logistic regression model that achieves good accuracy on the training set. Let's do that!

# %% [markdown]
# Use the learned coefficients to train a new feature extractor:

# %%
graph_gcn_filter = polynomial_graph_filter(coeff_gcn, laplacian)# Your code here

# %% [markdown]
# Let's extract the new features by filtering the data:

# %%
features_gcn = graph_gcn_filter @ features.numpy()

train_features_gcn = features_gcn[train_mask,:]
train_labels = labels[train_mask]
val_features_gcn = features_gcn[val_mask,:]
val_labels = labels[val_mask]
test_features_gcn = features_gcn[test_mask,:]
test_labels = labels[test_mask]

# %% [markdown]
# Train a logistic regression on these features:

# %%
# Your code here

# Fit a logistic regression model
# Your code here
from sklearn.metrics import accuracy_score
# 8e6
#C_param_range = [0.001,0.01,0.1,1,10,100, 1000, 5000, 1e4, 1e6, 8e6, 9e6, 1e7, 2e7,1e8]

try:
    C_param_range = np.arange(1e2, 1e3, 10)
    accuracies_train = []
    accuracies_val   = []
    params = []

    j = 0
    for i in C_param_range:

        # Apply logistic regression model to training data
        lr = LogisticRegression(penalty = 'l2', C = i, random_state = 0, solver='lbfgs', multi_class='multinomial', max_iter=1e5)

        # Predict using model
        y_pred_train = lr.fit(train_features, train_labels).predict(test_features)
        y_pred_val   = lr.fit(val_features, val_labels).predict(test_features)

        # Calculate accuracy
        acc_train = accuracy_score(test_labels, y_pred_train)
        acc_val   = accuracy_score(test_labels, y_pred_val)
        
        # Collect
        accuracies_train.append(acc_train)
        accuracies_val.append(acc_val)
        params.append(i)

except KeyboardInterrupt:
    pass
finally:
    plt.figure(figsize=(10,7))
    plt.plot(params, accuracies_train, label="train")
    plt.plot(params, accuracies_val, label="val")
    plt.legend()
    print(max(accuracies_train), max(accuracies_val))
# Out:
# 0.824 0.821

# %%
accuracies_mean = [ (t+v)/2 for (t, v) in zip(accuracies_train, accuracies_val)]
i = (np.argmax(accuracies_mean))
accuracies_mean[i], params[i], i
# Out:
# (0.822, 510.0, 41)

# %% [markdown]
# Finally, let's evaluate this model:

# %%
lr = LogisticRegression(penalty = 'l2', C = params[i], random_state = 0, solver='lbfgs', multi_class='multinomial', max_iter=1e5)
lr.fit(train_features, train_labels)

train_acc = lr.score(train_features, train_labels) # Your code here
val_acc =  lr.score(val_features, val_labels) # Your code here
test_acc = lr.score(test_features, test_labels)  # Your code here


print('Train accuracy {:.4f} | Validation accuracy {:.4f} | Test accuracy {:.4f}'.format(train_acc, val_acc, test_acc))
# Out:
# Train accuracy 0.8500 | Validation accuracy 0.8133 | Test accuracy 0.8240

# %% [markdown]
# The performance of this model may not be exactly the same as the one obtained with Pytorch. What are the differences in the training procedure that can explain this gap?

# %% [markdown]
# <div class="alert alert-info">
#     <b>ANSWER</b>
# </div>
